# %% [markdown]
# # CHILDREN'S BOOKS EDA AND DATA CLEANING

# %% [markdown]
# ## FIRST STEPS: IMPORTING THE LIBRARIES AND THE DATA

# %%
import pandas as pd
import numpy as np
import json
pd.options.display.max_rows=350
pd.options.display.max_columns=40
pd.options.mode.chained_assignment = None

# %%
filename = '../../datasets/goodreads_books_children.json'  #change your path here
data = pd.read_json(filename,lines=True)

# %%
books=data.copy()

# %% [markdown]
# # EDA AND DATA CLEANING

# %%
books.shape
# Out:
# (124082, 29)

# %%
books.head(3)
# Out:
#          isbn  text_reviews_count    series country_code language_code  \
# 0  1599150603                   7        []           US
# 1  1934876569                   6  [151854]           US
# 2  0590417010                 193        []           US           eng
#
#                                      popular_shelves asin is_ebook  \
# 0  [{'count': '56', 'name': 'to-read'}, {'count':...         false
# 1  [{'count': '515', 'name': 'to-read'}, {'count'...         false
# 2  [{'count': '450', 'name': 'to-read'}, {'count'...         false
#
#    average_rating kindle_asin  \
# 0            4.13  B00DU10PUG
# 1            4.22
# 2            4.43  B017RORXNI
#
#                                        similar_books  \
# 0                                                 []
# 1  [948696, 439885, 274955, 12978730, 372986, 216...
# 2  [834493, 452189, 140185, 1897316, 2189812, 424...
#
#                                          description     format  \
# 0  Relates in vigorous prose the tale of Aeneas, ...  Paperback
# 1  To Kara's astonishment, she discovers that a p...  Paperback
# 2  In Newbery Medalist Cynthia Rylant's classic b...  Hardcover
#
#                                                 link  \
# 0  https://www.goodreads.com/book/show/287141.The...
# 1  https://www.goodreads.com/book/show/6066812-al...
# 2  https://www.goodreads.com/book/show/89378.Dog_...
#
#                                   authors             publisher num_pages  \
# 0  [{'author_id': '3041852', 'role': ''}]  Yesterday's Classics       162
# 1    [{'author_id': '19158', 'role': ''}]            Seven Seas       216
# 2     [{'author_id': '5411', 'role': ''}]        Blue Sky Press        40
#
#   publication_day         isbn13 publication_month edition_information  \
# 0              13  9781599150604                 9
# 1               3  9781934876565                 3
# 2               1  9780590417013                 9
#
#   publication_year                                                url  \
# 0             2006  https://www.goodreads.com/book/show/287141.The...
# 1             2009  https://www.goodreads.com/book/show/6066812-al...
# 2             1995  https://www.goodreads.com/book/show/89378.Dog_...
#
#                                            image_url  book_id  ratings_count  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...   287141             46
# 1  https://images.gr-assets.com/books/1316637798m...  6066812             98
# 2  https://images.gr-assets.com/books/1360057676m...    89378           1331
#
#    work_id                                              title  \
# 0   278578                      The Aeneid for Boys and Girls
# 1   701117  All's Fairy in Love and War (Avalon: Web of Ma...
# 2    86259                                         Dog Heaven
#
#                                 title_without_series
# 0                      The Aeneid for Boys and Girls
# 1  All's Fairy in Love and War (Avalon: Web of Ma...
# 2                                         Dog Heaven

# %%
books.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'series', 'country_code', 'language_code',
#        'popular_shelves', 'asin', 'is_ebook', 'average_rating', 'kindle_asin',
#        'similar_books', 'description', 'format', 'link', 'authors',
#        'publisher', 'num_pages', 'publication_day', 'isbn13',
#        'publication_month', 'edition_information', 'publication_year', 'url',
#        'image_url', 'book_id', 'ratings_count', 'work_id', 'title',
#        'title_without_series'],
#       dtype='object')

# %% [markdown]
# ## Dropping some columns without meaninful information

# %%
books=books.drop(['series','country_code','popular_shelves', 'asin', 'similar_books','kindle_asin','publication_day', 'publication_month', 'edition_information','work_id','authors', 'image_url','link','url','title_without_series'], axis = 1)

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124082 entries, 0 to 124081
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   isbn                124082 non-null  object
#  1   text_reviews_count  124082 non-null  int64
#  2   language_code       124082 non-null  object
#  3   is_ebook            124082 non-null  object
#  4   average_rating      124082 non-null  float64
#  5   description         124082 non-null  object
#  6   format              124082 non-null  object
#  7   publisher           124082 non-null  object
#  8   num_pages           124082 non-null  object
#  9   isbn13              124082 non-null  object
#  10  publication_year    124082 non-null  object
#  11  book_id             124082 non-null  int64
#  12  ratings_count       124082 non-null  int64
#  13  title               124082 non-null  object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 13.3+ MB

# %% [markdown]
# At a first glance we have 4 numerical variables and 10 categorical variables, but it looks like num_pages, isbn, isbn13, and publication_year should be integers instead of objects.
# There are no null values in the dataset, so there has to be some noise or maybe missing values inside these columns,  which prevent them from being considered as numerical variables.

# %% [markdown]
# ## Ckecking if there are duplicates in the dataframe

# %%
books.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates in the dataframe.

# %% [markdown]
# ## Getting the unique values in each column

# %%
def get_uniques(df,lim=20):
    for col in df.columns:
        array=list(df[col].values)
        uniques=set(array)
        if len(uniques) < lim:
            print(col, ":", uniques)
        else:
            print(col, ":", len(uniques), "unique values.")

# %%
get_uniques(books)
# Out:
# isbn : 103884 unique values.
# text_reviews_count : 1040 unique values.
# language_code : 90 unique values.
# is_ebook : {'true', 'false'}
# average_rating : 299 unique values.
# description : 94613 unique values.
# format : 209 unique values.
# publisher : 11651 unique values.
# num_pages : 790 unique values.
# isbn13 : 108594 unique values.
# publication_year : 192 unique values.
# book_id : 124082 unique values.
# ratings_count : 4433 unique values.
# title : 96354 unique values.

# %% [markdown]
# ## Univariable analysis

# %% [markdown]
# ### Numerical variables

# %%
books.describe().T
# Out:
#                        count          mean           std  min         25%  \
# text_reviews_count  124082.0  2.708621e+01  2.665470e+02  0.0        2.00
# average_rating      124082.0  3.910883e+00  3.648551e-01  0.0        3.71
# book_id             124082.0  1.057929e+07  1.017990e+07  5.0  1414649.50
# ratings_count       124082.0  5.228165e+02  1.083869e+04  0.0       10.00
#
#                            50%          75%         max
# text_reviews_count        5.00        15.00     49850.0
# average_rating            3.94         4.14         5.0
# book_id             7068956.00  18165059.25  36469877.0
# ratings_count            30.00        96.00   1876252.0

# %% [markdown]
# #### Book ID

# %% [markdown]
# The column book_id is the only variable having 124082 unique values. Every value respond to one goodread book page.

# %%
books.book_id.nunique()
# Out:
# 124082

# %%
books[books.book_id == 5]
# Out:
#              isbn  text_reviews_count language_code is_ebook  average_rating  \
# 53726  043965548X               28561           eng    false            4.53
#
#                                              description  \
# 53726  Harry Potter's third year at Hogwarts is full ...
#
#                       format        publisher num_pages         isbn13  \
# 53726  Mass Market Paperback  Scholastic Inc.       435  9780439655484
#
#       publication_year  book_id  ratings_count  \
# 53726             2004        5        1876252
#
#                                                    title
# 53726  Harry Potter and the Prisoner of Azkaban (Harr...

# %% [markdown]
# #### Text Reviews Count

# %% [markdown]
# The column text_reviews_count, tells us the number of reviews for each book_id of the dataset. The minimum is 0 and the maximum 49850. So we can see there are books much more popular than others.

# %%
books.text_reviews_count.value_counts()
# Out:
# 1        21107
# 2        15054
# 3        11395
# 4         8753
# 5         7015
#          ...
# 987          1
# 3290         1
# 1627         1
# 11870        1
# 7868         1
# Name: text_reviews_count, Length: 1040, dtype: int64

# %%
books[books.text_reviews_count== 49850]
# Out:
#               isbn  text_reviews_count language_code is_ebook  average_rating  \
# 110278  0385732554               49850           eng    false            4.12
#
#                                               description     format  \
# 110278  Twelve-year-old Jonas lives in a seemingly ide...  Paperback
#
#        publisher num_pages         isbn13 publication_year  book_id  \
# 110278     Ember       208  9780385732550             2006     3636
#
#         ratings_count                      title
# 110278        1311422  The Giver (The Giver, #1)

# %% [markdown]
# The book with the maximum number of text reviews is The Giver, this book have also 1311422 ratings count.

# %%
books[books.text_reviews_count== 0].title.count()
# Out:
# 15

# %%
books[books.text_reviews_count== 0].title
# Out:
# 10853                                    James and the Mini
# 22957                      Alice's Adventures in Wonderland
# 26069                                     Muumipeikko herää
# 31913                                           Hoàng Tử Bé
# 32681                                The Story of Christmas
# 44094                        Sagwa, the Chinese Siamese Cat
# 57177                          The Mystery of the Wrong Dog
# 67331                           Laika: The 1st Dog in Space
# 72909                                            Büyülü Kuş
# 95282     Lego Ninjago: Masters of Spinjitzu: Official G...
# 95815                      Alice's Adventures in Wonderland
# 99336                           My Name is Oscar the Grouch
# 100312                                       In My Backyard
# 107820    DORK Diaries 02. Nikkis (nicht ganz so) glamou...
# 114660                                     Figgs & Phantoms
# Name: title, dtype: object

# %%
books[books.text_reviews_count== 0].ratings_count
# Out:
# 10853      5
# 22957     56
# 26069      1
# 31913      8
# 32681     28
# 44094      7
# 57177     46
# 67331      0
# 72909      5
# 95282     39
# 95815     38
# 99336      3
# 100312     3
# 107820    51
# 114660     7
# Name: ratings_count, dtype: int64

# %% [markdown]
# There are 15 books with 0 text reviews, few of them are in minority languages. These books don't have many ratings either.

# %% [markdown]
# #### Rating counts

# %% [markdown]
# ratings_count goes from 0.0 to 1876252 , but the most of the sample ranges between 10 and 96.

# %%
books[books.ratings_count== 1876252]
# Out:
#              isbn  text_reviews_count language_code is_ebook  average_rating  \
# 53726  043965548X               28561           eng    false            4.53
#
#                                              description  \
# 53726  Harry Potter's third year at Hogwarts is full ...
#
#                       format        publisher num_pages         isbn13  \
# 53726  Mass Market Paperback  Scholastic Inc.       435  9780439655484
#
#       publication_year  book_id  ratings_count  \
# 53726             2004        5        1876252
#
#                                                    title
# 53726  Harry Potter and the Prisoner of Azkaban (Harr...

# %%
books[books.ratings_count== 0].title.count()
# Out:
# 316

# %% [markdown]
# There are 316 books without any rating count, let's drop these books.

# %%
books.shape
# Out:
# (124082, 14)

# %%
books=books[books.ratings_count!= 0]

# %%
books.shape
# Out:
# (123766, 14)

# %%
books.describe()
# Out:
#        text_reviews_count  average_rating       book_id  ratings_count
# count       123766.000000   123766.000000  1.237660e+05   1.237660e+05
# mean            27.152796        3.911681  1.056636e+07   5.241514e+02
# std            266.883826        0.360879  1.017666e+07   1.085249e+04
# min              0.000000        1.000000  5.000000e+00   1.000000e+00
# 25%              2.000000        3.710000  1.413372e+06   1.000000e+01
# 50%              5.000000        3.940000  7.049316e+06   3.100000e+01
# 75%             15.000000        4.140000  1.815477e+07   9.600000e+01
# max          49850.000000        5.000000  3.646988e+07   1.876252e+06

# %% [markdown]
# #### Average rating

# %% [markdown]
# The average rating ranges from 1 to 5. Being the mean 3.91

# %%
books[books.average_rating == 1].title.count()
# Out:
# 10

# %%
books[books.average_rating == 1].ratings_count
# Out:
# 29219    1
# 30726    1
# 31565    1
# 32445    1
# 38341    1
# 40781    1
# 42742    3
# 56489    1
# 78572    1
# 96827    1
# Name: ratings_count, dtype: int64

# %%
books[books.average_rating == 5].title.count()
# Out:
# 388

# %% [markdown]
# ### Categorical variables that should be numerical

# %% [markdown]
# #### ISBN

# %%
books.isbn.value_counts()
# Out:
#               20129
# 078577842X        1
# 0746073356        1
# 0060734663        1
# 1519549466        1
#               ...
# 0380977176        1
# 0061234753        1
# 1619630451        1
# 1627552987        1
# 2070612384        1
# Name: isbn, Length: 103638, dtype: int64

# %% [markdown]
# There are 20129 missing values in the column isbn. The rest of the books have an unique isbn.

# %% [markdown]
# #### ISBN 13

# %%
books.isbn13.value_counts()
# Out:
#                  15436
# 9780439057493        1
# 9780763659837        1
# 9780803730960        1
# 9780670852529        1
#                  ...
# 9780152057770        1
# 9780747562832        1
# 9780679892281        1
# 9781402258893        1
# 9780066238685        1
# Name: isbn13, Length: 108331, dtype: int64

# %% [markdown]
# There are 15436 missing values in the column isbn13. The rest of the books have an unique isbn.

# %% [markdown]
# An ISBN is an International Standard Book Number. ISBNs were 10 digits in length up to the end of December 2006, but since 1 January 2007 they now always consist of 13 digits. ISBNs are calculated using a specific mathematical formula and include a check digit to validate the number.
# An ISBN is essentially a product identifier used by publishers, booksellers, libraries, internet retailers and other supply chain participants for ordering, listing, sales records and stock control purposes. The ISBN identifies the registrant as well as the specific title, edition and format.
#
# ISBNs are assigned to text-based monographic publications (i.e. one-off publications rather than journals, newspapers, or other types of serials).Any book made publicly available, whether for sale or on a gratis basis, can be identified by ISBN.

# %% [markdown]
# Let's check which books have both (the isbn and the isbn13) missing values.

# %%
books[(books.isbn == '') & (books.isbn13== '')].shape
# Out:
# (12882, 14)

# %% [markdown]
# There are 12882 books without any kind of isbn. Let's drop them.

# %%
books=books[(books.isbn != '')|(books.isbn13!= '')]

# %%
books.shape
# Out:
# (110884, 14)

# %%
books.isbn.value_counts()
# Out:
#               7247
# 078577842X       1
# 0746073356       1
# 0060734663       1
# 1519549466       1
#               ...
# 0380977176       1
# 0061234753       1
# 1619630451       1
# 1627552987       1
# 2070612384       1
# Name: isbn, Length: 103638, dtype: int64

# %%
books.isbn13.value_counts()
# Out:
#                  2554
# 9780439057493       1
# 9780763659837       1
# 9780803730960       1
# 9780670852529       1
#                  ...
# 9780152057770       1
# 9780747562832       1
# 9780679892281       1
# 9781402258893       1
# 9780066238685       1
# Name: isbn13, Length: 108331, dtype: int64

# %% [markdown]
# #### Number of Pages

# %% [markdown]
# The num_pages variable should contain integers but it contains strings. Some of them could have sense if the format of the book is for example audio, but it's not the case of all of them.
# There are many missing values in this column. Should we drop them or scrap them and add them to the column?
# There are also books with more than 3000 words (I suppose these might be collections), and also books with just 1 or two pages.
# Let's check them.

# %%
books.num_pages.value_counts()
# Out:
# 32      23485
#         21079
# 40       6042
# 24       4430
# 48       3474
#         ...
# 566         1
# 731         1
# 621         1
# 471         1
# 1293        1
# Name: num_pages, Length: 757, dtype: int64

# %%
books.num_pages.nunique()
# Out:
# 757

# %%
books[books.num_pages== ''].format.value_counts()
# Out:
#                                   11480
# Hardcover                          4212
# Paperback                          3047
# Audio CD                            647
# ebook                               362
# Audio                               360
# Unknown Binding                     223
# Audiobook                           200
# Board Book                          197
# Board book                           66
# Library Binding                      65
# Audio Cassette                       36
# Mass Market Paperback                34
# Boxed Set                            21
# School &amp; Library Binding         15
# paperback                            12
# Kindle Edition                       12
# Audible Audio                         9
# Gebundene Ausgabe                     7
# Spiral-bound                          7
# MP3 CD                                6
# audio                                 5
# Bath Book                             4
# board book (lift the flap)            4
# Turtleback                            3
# Novelty Book                          3
# tjlyd fkhr                            2
# Nook                                  2
# Paperback with CD                     2
# Playaway                              2
# hardback                              2
# Poche                                 1
# Hardcover Comic                       1
# Collector's Edition                   1
# hardcover                             1
# Broschiert                            1
# thlth 'jz fy mGlf wHd                 1
# Paperback Boxed Set                   1
# Misc. Supplies                        1
# Playaway Audiobook                    1
# Leather Bound                         1
# Hardcover + 2 CDs                     1
# Clothbound Hardback                   1
# Preloaded Digital Audio Player        1
# Hardcover Novelty Book                1
# Hardcover (Pop-Up Boxed Set)          1
# Broche                                1
# pop up book                           1
# hard cover                            1
# Pop-Up Book                           1
# audio cassette                        1
# MP3 Audio                             1
# audio CD                              1
# Paperback with Audio Cassette         1
# Book on CD                            1
# Binder-Bound                          1
# Brochura                              1
# Book + Cassette                       1
# Novelty                               1
# Hardcover and CD                      1
# Glf `dy, 21x21                        1
# Unbound                               1
# picture book                          1
# Name: format, dtype: int64

# %%
books[books.num_pages== '1'].format.value_counts()
# Out:
# Audio CD          25
# Hardcover         23
# Audiobook         16
# Paperback          8
# Audio              3
# Board book         3
#                    1
# DVD                1
# Audio Cassette     1
# Name: format, dtype: int64

# %% [markdown]
# #### Publication year

# %%
books.publication_year.value_counts()
# Out:
#          13373
# 2013      5855
# 2014      5755
# 2012      5466
# 2015      5315
# 2016      4978
# 2011      4808
# 2010      4426
# 2008      4101
# 2009      4050
# 2007      3933
# 2006      3629
# 2005      3390
# 2017      3193
# 2004      3187
# 2003      3023
# 2002      2701
# 2001      2495
# 2000      2462
# 1999      2215
# 1998      2061
# 1997      1889
# 1996      1758
# 1995      1520
# 1994      1428
# 1993      1357
# 1992      1229
# 1991      1048
# 1990       928
# 1989       916
# 1988       852
# 1987       728
# 1986       586
# 1985       540
# 1984       494
# 1983       415
# 1982       362
# 1980       328
# 1981       318
# 1978       301
# 1977       289
# 1979       275
# 1976       223
# 1973       213
# 1974       204
# 1975       204
# 1972       170
# 1971       165
# 1970       163
# 1969       132
# 1968       114
# 1967       107
# 1966        85
# 2018        82
# 1962        73
# 1963        70
# 1961        70
# 1965        68
# 1964        63
# 1960        57
# 1958        45
# 1950        42
# 1959        41
# 1957        37
# 1953        34
# 1956        30
# 1948        29
# 1954        27
# 1952        26
# 1955        24
# 1951        22
# 1949        21
# 1947        20
# 1945        19
# 1900        12
# 1940        12
# 1930        11
# 1946        11
# 1941        10
# 1942         9
# 1936         9
# 1939         8
# 1943         7
# 1938         7
# 1931         6
# 1934         6
# 1944         6
# 1937         5
# 1932         5
# 1909         4
# 1927         4
# 1924         4
# 1928         4
# 16           4
# 1933         4
# 1910         3
# 1903         3
# 1925         3
# 1923         3
# 1935         3
# 1901         3
# 1929         2
# 15           2
# 2103         2
# 1378         2
# 1393         2
# 1912         2
# 1384         2
# 1906         2
# 1907         2
# 1920         2
# 1926         2
# 19983        1
# 20116        1
# 211          1
# 199          1
# 2030         1
# 104          1
# 32           1
# 21017        1
# 1899         1
# 1394         1
# 1915         1
# 1381         1
# 5            1
# 1877         1
# 1922         1
# 1387         1
# 20125        1
# 214          1
# 200          1
# 2091         1
# 13           1
# 20012        1
# 1914         1
# 1921         1
# 1905         1
# 1383         1
# 1392         1
# 1897         1
# 1919         1
# 20011        1
# 1395         1
# 1904         1
# 65535        1
# 1902         1
# 2104         1
# 213          1
# 14           1
# 215          1
# 201          1
# Name: publication_year, dtype: int64

# %% [markdown]
# There are 13373 missing values in publication year.
# The most of the books in which we know the publication year, range between 1960 and 2017.
# There are weird values like with more than 4 digits and also less than 14 digits.
# We should drop the rows presenting missing values and weird values.

# %%
books.drop(books[books.publication_year == ''].index, inplace=True)

# %%
books.publication_year=pd.to_numeric(books.publication_year)

# %%
books.publication_year.describe().T
# Out:
# count    97511.000000
# mean      2005.754756
# std        250.288665
# min          5.000000
# 25%       1999.000000
# 50%       2007.000000
# 75%       2013.000000
# max      65535.000000
# Name: publication_year, dtype: float64

# %%
books.drop(books[books.publication_year <= 1800].index, inplace = True)

# %%
books.drop(books[books.publication_year >= 2019].index, inplace = True)

# %%
books.publication_year.describe().T
# Out:
# count    97469.000000
# mean      2004.407196
# std         11.333694
# min       1877.000000
# 25%       1999.000000
# 50%       2007.000000
# 75%       2013.000000
# max       2018.000000
# Name: publication_year, dtype: float64

# %%
books.shape
# Out:
# (97469, 14)

# %% [markdown]
# ### Rest of categorical variables

# %% [markdown]
# #### Description

# %% [markdown]
# There are 7029 books without description. The description column is one of the most important for our model, so let's drop all rows in wich the description is missing.
# There are also different books sharing the same description, but we will deal with that later.

# %%
books.description.value_counts()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           7029
# Source of legend and lyric, reference and conjecture, Alice's Adventures in Wonderland is for most children pure pleasure in prose. While adults try to decipher Lewis Carroll's putative use of complex mathematical codes in the text, or debate his alleged use of opium, young readers simply dive with Alice through the rabbit hole, pursuing "The dream-child moving through a land / Of wonders wild and new." There they encounter the White Rabbit, the Queen of Hearts, the Mock Turtle, and the Mad Hatter, among a multitude of other characters--extinct, fantastical, and commonplace creatures. Alice journeys through this Wonderland, trying to fathom the meaning of her strange experiences. But they turn out to be "curiouser and curiouser," seemingly without moral or sense.\nFor more than 130 years, children have reveled in the delightfully non-moralistic, non-educational virtues of this classic. In fact, at every turn, Alice's new companions scoff at her traditional education. The Mock Turtle, for example, remarks that he took the "regular course" in school: Reeling, Writhing, and branches of Arithmetic-Ambition, Distraction, Uglification, and Derision. Carroll believed John Tenniel's illustrations were as important as his text. Naturally, Carroll's instincts were good; the masterful drawings are inextricably tied to the well-loved story.      62
# Follow the yellow brick road!\nDorothy thinks she's lost forever when a tornado whirls her and her dog, Toto, into a magical world. To get home, she must find the wonderful wizard in the Emerald City of Oz. On the way she meets the Scarecrow, the Tin Woodman and the Cowardly Lion. But the Wicked Witch of the West has her own plans for the new arrival - will Dorothy ever see Kansas again?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      46
# Boyds Mills Press publishes a wide range of high-quality fiction and nonfiction picture books, chapter books, novels, and nonfiction                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        45
# Moral allegory and spiritual autobiography, The Little Prince is the most translated book in the French language. With a timeless charm it tells the story of a little boy who leaves the safety of his own tiny planet to travel the universe, learning the vagaries of adult behaviour through a series of extraordinary encounters. His personal odyssey culminates in a voyage to Earth and further adventures.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         44
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# Early Sunday Morningis the first offering from Denene Millner Books, the new children's line published under Agate's Bolden imprint in partnership with Denene Millner, the noted parenting authority, editor, and New York Times bestselling author.\nLove and family. These are the things that a little girl finds most special about Sunday mornings. Early Sunday Morningfollows June, Mommy, Daddy, and brother Troy through their weekend routine as June prepares for a special performance leading the children's choir at church on Sunday morning.\nReaders spend the weekend with June as she collects helpful pieces of advice on how to be less nervous about her big solo. Along the way, she visits the barbershop with Mommy and Troy, gets her hair done by Mommy, receives a special dress from her aunt, and shares her family ritual of getting ready for Sunday morning service. As her special moment approaches, June leans on the support of her whole family, as well as advice from her father, to conquer her fear of singing in front of the congregation.\nEarly Sunday Morningis a heartwarming celebration of the special time a young girl and her family share together as she learns how to lift her mighty voice.                                                                                                                                                        1
# Paddington, the first-ever live action film with CGI animation based on the classic book series by Michael Bond lights up theaters Christmas Day 2014.\nMeet Paddington, the extraordinary bear from Peru, and his many friends who help him out of lots of curious situations-as well as a few characters who lead him into trouble! Filled with full-color images from the film, Paddington, this Level One I Can Read storybook is an exciting introduction to this classic character.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# With bounding glee, Steven Kellogg brings to life the legend of Paul Bunyan. Together with his blue ox Babe and his crew, Paul Bunyan fights the wild Gumberoos, digs out the Great Lakes and gouges out the Grand Canyon. Paul Bunyan and Steven Kellogg--a splendid pair indeed!--Booklist. Full-color illus.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# It's Christmas Eve, Have you been good? Santa's packed up all the presents and is headed your way! With the help of a certain red-nosed reindeer, Santa flies over:\n-Columbia Center\n-Experience Music Project\n-Science Fiction Museum\n-Great Northern Railway\n-Depot Tower\n-Mount St. Helen's\n-Museum of Glass\n-Seattle Public Library\n-Smith Tower\n-Space Needle\n-Tacoma Bridge\n-US Post Office\n"Ho, ho ho!" laughs Santa. "Merry Christmas, Washington!"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# "If Julian has not already won readers' hearts with his [earlier] exploits, he will here when he tries to find out his father's secret dream for a birthday present. Surprised at hearing his father mumble 'two snakes,' Julian duly catches and presents them, only to discover that snakes are his father's recurring nightmare. Cameron's style is elegantly smooth and the characters come alive through easy dialogue and involving action."--Bulletin, Center for Children's Books.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Name: description, Length: 82694, dtype: int64

# %%
books1=books[books.description != '']

# %%
books1.shape
# Out:
# (90440, 14)

# %% [markdown]
# So there are 90440 books including a description.

# %%
books1.description.value_counts()
# Out:
# Source of legend and lyric, reference and conjecture, Alice's Adventures in Wonderland is for most children pure pleasure in prose. While adults try to decipher Lewis Carroll's putative use of complex mathematical codes in the text, or debate his alleged use of opium, young readers simply dive with Alice through the rabbit hole, pursuing "The dream-child moving through a land / Of wonders wild and new." There they encounter the White Rabbit, the Queen of Hearts, the Mock Turtle, and the Mad Hatter, among a multitude of other characters--extinct, fantastical, and commonplace creatures. Alice journeys through this Wonderland, trying to fathom the meaning of her strange experiences. But they turn out to be "curiouser and curiouser," seemingly without moral or sense.\nFor more than 130 years, children have reveled in the delightfully non-moralistic, non-educational virtues of this classic. In fact, at every turn, Alice's new companions scoff at her traditional education. The Mock Turtle, for example, remarks that he took the "regular course" in school: Reeling, Writhing, and branches of Arithmetic-Ambition, Distraction, Uglification, and Derision. Carroll believed John Tenniel's illustrations were as important as his text. Naturally, Carroll's instincts were good; the masterful drawings are inextricably tied to the well-loved story.    62
# Follow the yellow brick road!\nDorothy thinks she's lost forever when a tornado whirls her and her dog, Toto, into a magical world. To get home, she must find the wonderful wizard in the Emerald City of Oz. On the way she meets the Scarecrow, the Tin Woodman and the Cowardly Lion. But the Wicked Witch of the West has her own plans for the new arrival - will Dorothy ever see Kansas again?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    46
# Boyds Mills Press publishes a wide range of high-quality fiction and nonfiction picture books, chapter books, novels, and nonfiction                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      45
# Moral allegory and spiritual autobiography, The Little Prince is the most translated book in the French language. With a timeless charm it tells the story of a little boy who leaves the safety of his own tiny planet to travel the universe, learning the vagaries of adult behaviour through a series of extraordinary encounters. His personal odyssey culminates in a voyage to Earth and further adventures.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       44
# By falling down a rabbit hole and stepping through a mirror, Alice experiences unusual adventures with a variety of nonsensical characters.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               38
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ..
# Barkley is a great circus dog. He can walk on his front legs, and he can walk on his back legs.\nBut Barkley is getting to be a great oldcircus dog. He can't keep up with the younger dogs, and he has problems when he joins the other acts. Soon he thinks he will have to leave the circus and the children he loves.\nFunny and sad, Barkley joins Syd Hoff 's inimitable cast of characters. Children who love dogs and circuses will love Barkley.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# Early Sunday Morningis the first offering from Denene Millner Books, the new children's line published under Agate's Bolden imprint in partnership with Denene Millner, the noted parenting authority, editor, and New York Times bestselling author.\nLove and family. These are the things that a little girl finds most special about Sunday mornings. Early Sunday Morningfollows June, Mommy, Daddy, and brother Troy through their weekend routine as June prepares for a special performance leading the children's choir at church on Sunday morning.\nReaders spend the weekend with June as she collects helpful pieces of advice on how to be less nervous about her big solo. Along the way, she visits the barbershop with Mommy and Troy, gets her hair done by Mommy, receives a special dress from her aunt, and shares her family ritual of getting ready for Sunday morning service. As her special moment approaches, June leans on the support of her whole family, as well as advice from her father, to conquer her fear of singing in front of the congregation.\nEarly Sunday Morningis a heartwarming celebration of the special time a young girl and her family share together as she learns how to lift her mighty voice.                                                                                                                                                      1
# Paddington, the first-ever live action film with CGI animation based on the classic book series by Michael Bond lights up theaters Christmas Day 2014.\nMeet Paddington, the extraordinary bear from Peru, and his many friends who help him out of lots of curious situations-as well as a few characters who lead him into trouble! Filled with full-color images from the film, Paddington, this Level One I Can Read storybook is an exciting introduction to this classic character.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# With bounding glee, Steven Kellogg brings to life the legend of Paul Bunyan. Together with his blue ox Babe and his crew, Paul Bunyan fights the wild Gumberoos, digs out the Great Lakes and gouges out the Grand Canyon. Paul Bunyan and Steven Kellogg--a splendid pair indeed!--Booklist. Full-color illus.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# "If Julian has not already won readers' hearts with his [earlier] exploits, he will here when he tries to find out his father's secret dream for a birthday present. Surprised at hearing his father mumble 'two snakes,' Julian duly catches and presents them, only to discover that snakes are his father's recurring nightmare. Cameron's style is elegantly smooth and the characters come alive through easy dialogue and involving action."--Bulletin, Center for Children's Books.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# Name: description, Length: 82693, dtype: int64

# %%
# But there are several books sharing the same description

# %%
books1[books1.description =='By falling down a rabbit hole and stepping through a mirror, Alice experiences unusual adventures with a variety of nonsensical characters.']
# Out:
#               isbn  text_reviews_count language_code is_ebook  average_rating  \
# 223                                  4           eng    false            4.06
# 4018    0922984018                   1           eng    false            4.06
# 4491     044860043                   1           eng    false            4.06
# 6108    0451512790                  11           eng    false            4.06
# 6316    8477024472                   1           spa    false            4.06
# 8231                                 2           spa    false            4.06
# 9324    0716631989                   1                  false            4.06
# 19874   1847494072                   9           eng    false            4.06
# 25165   1907360360                   5         en-US    false            4.06
# 30876   8889145439                   3           ita    false            4.06
# 33047   1858135613                   8           eng    false            4.06
# 37221   145057761X                   3                  false            4.06
# 40536   0307671119                   8                  false            4.06
# 40537   044805454X                   4           eng    false            4.06
# 42332   0706407881                   2           eng    false            4.06
# 42483   0448058049                   5                  false            4.06
# 56167                                2           eng    false            4.06
# 59084   8804480475                   9           ita    false            4.06
# 62951   1435136314                  30           eng    false            4.06
# 64557   1840022566                   9                  false            4.06
# 64823   1593080158                 235           eng    false            4.06
# 68929   0451520084                   2         en-US    false            4.06
# 74630   8420691739                   2           spa    false            4.06
# 81630   0451523202                  13           eng    false            4.06
# 90587   0831766948                   2                  false            4.06
# 95141   9512007835                   5           fin    false            4.06
# 95734   158726532X                   3           eng    false            4.06
# 98671                                1           cze    false            4.06
# 99117   0563536853                   1           eng    false            4.06
# 102094  1840813520                   3           eng    false            4.06
# 104156  8497897013                   3           eng    false            4.06
# 106009  2070389162                   3           fre    false            4.06
# 108990  0307290875                  15           eng    false            4.06
# 114315  1865150045                   1           eng    false            4.06
# 117691  0760716196                  44           eng    false            4.06
# 119646  3865055109                   6           eng    false            4.06
# 121850  1560772603                   2                  false            4.06
# 123198  1853261181                  21           eng    false            4.06
#
#                                               description  \
# 223     By falling down a rabbit hole and stepping thr...
# 4018    By falling down a rabbit hole and stepping thr...
# 4491    By falling down a rabbit hole and stepping thr...
# 6108    By falling down a rabbit hole and stepping thr...
# 6316    By falling down a rabbit hole and stepping thr...
# 8231    By falling down a rabbit hole and stepping thr...
# 9324    By falling down a rabbit hole and stepping thr...
# 19874   By falling down a rabbit hole and stepping thr...
# 25165   By falling down a rabbit hole and stepping thr...
# 30876   By falling down a rabbit hole and stepping thr...
# 33047   By falling down a rabbit hole and stepping thr...
# 37221   By falling down a rabbit hole and stepping thr...
# 40536   By falling down a rabbit hole and stepping thr...
# 40537   By falling down a rabbit hole and stepping thr...
# 42332   By falling down a rabbit hole and stepping thr...
# 42483   By falling down a rabbit hole and stepping thr...
# 56167   By falling down a rabbit hole and stepping thr...
# 59084   By falling down a rabbit hole and stepping thr...
# 62951   By falling down a rabbit hole and stepping thr...
# 64557   By falling down a rabbit hole and stepping thr...
# 64823   By falling down a rabbit hole and stepping thr...
# 68929   By falling down a rabbit hole and stepping thr...
# 74630   By falling down a rabbit hole and stepping thr...
# 81630   By falling down a rabbit hole and stepping thr...
# 90587   By falling down a rabbit hole and stepping thr...
# 95141   By falling down a rabbit hole and stepping thr...
# 95734   By falling down a rabbit hole and stepping thr...
# 98671   By falling down a rabbit hole and stepping thr...
# 99117   By falling down a rabbit hole and stepping thr...
# 102094  By falling down a rabbit hole and stepping thr...
# 104156  By falling down a rabbit hole and stepping thr...
# 106009  By falling down a rabbit hole and stepping thr...
# 108990  By falling down a rabbit hole and stepping thr...
# 114315  By falling down a rabbit hole and stepping thr...
# 117691  By falling down a rabbit hole and stepping thr...
# 119646  By falling down a rabbit hole and stepping thr...
# 121850  By falling down a rabbit hole and stepping thr...
# 123198  By falling down a rabbit hole and stepping thr...
#
#                        format  \
# 223                 Paperback
# 4018                Hardcover
# 4491                Hardcover
# 6108    Mass Market Paperback
# 6316                Paperback
# 8231                Paperback
# 9324          Unknown Binding
# 19874               Paperback
# 25165               Hardcover
# 30876               Hardcover
# 33047               Paperback
# 37221               Paperback
# 40536               Hardcover
# 40537               Hardcover
# 42332               Hardcover
# 42483               Hardcover
# 56167               Paperback
# 59084               Paperback
# 62951               Hardcover
# 64557               Paperback
# 64823               Paperback
# 68929
# 74630               Paperback
# 81630               Paperback
# 90587               Hardcover
# 95141               Hardcover
# 95734               Hardcover
# 98671               Hardcover
# 99117                Audio CD
# 102094              Hardcover
# 104156              Hardcover
# 106009  Mass Market Paperback
# 108990              Paperback
# 114315              Hardcover
# 117691
# 119646                 MP3 CD
# 121850           Spiral-bound
# 123198              Paperback
#
#                                                 publisher num_pages  \
# 223                                      Sweetwater Press       272
# 4018                                       Wellington Pub       165
# 4491                         Grosset & Dunlap, Publishers       307
# 6108                                      Signet Classics
# 6316                                             Valdemar
# 8231                                    Ediciones Brontes       187
# 9324                                           World Book       248
# 19874                                       Alma Classics       384
# 25165                                 Collector's Library       288
# 30876                        Gruppo Editoriale L'Espresso       320
# 33047                                       Parragon Plus
# 37221                                         Createspace       130
# 40536                                        Golden Books       254
# 40537                              Grosset & Dunlap, INC.       278
# 42332                                       Smithmark Pub       416
# 42483                                   Grosset  & Dunlap       295
# 56167                                      SIS PUBLISHING       182
# 59084                                           Mondadori       282
# 62951                             Sterling Publishing Co.       242
# 64557                                        Oberon Books       120
# 64823                              Barnes  Noble Classics       286
# 68929                                     Signet Classics       238
# 74630                                Alianza Editorial SA
# 81630                                     Signet Classics       240
# 90587                                Smithmark Publishers       312
# 95141                                            Gummerus       283
# 95734                                    Borders Classics       172
# 98671                                     Levne knihy KMa       165
# 99117                                           BBC Books         0
# 102094                                                          307
# 104156                                    Signet Classics
# 106009                                Gallimard Education       371
# 108990                             Knopf Publishing Group       327
# 114315  Redwood Editions, a division of Hinkler Book D...       307
# 117691                            Wordsworth Editions Ltd       264
# 119646                                  Bertz und Fischer       448
# 121850                                Center for Learning
# 123198                            Wordsworth Editions Ltd       264
#
#                isbn13  publication_year   book_id  ratings_count  \
# 223     9781784284268              2017  34457541             19
# 4018    9780922984015              1991   5135797              3
# 4491                               1980  15809676             20
# 6108    9780451512796              1960   1503618            111
# 6316    9788477024477              2006  12228349              5
# 8231    9788496975668              2010  18141618             20
# 9324    9780716631989              1988   4930110              8
# 19874   9781847494078              2015  25231788             85
# 25165   9781907360367              2011  13664833             67
# 30876   9788889145432              2004  15735794             21
# 33047   9781858135618              1996   1921794             55
# 37221   9781450577618              2010   7814814             25
# 40536   9780307671110              1986   1124898            431
# 40537   9780448054544              1970   1124896             33
# 42332   9780706407884              1978   2368552             11
# 42483   9780448058047              1974    806282             94
# 56167   9786055768805              2012  22737696              5
# 59084   9788804480471              2003   7725882            169
# 62951   9781435136311              2012  17352567            172
# 64557   9781840022568              2002    138521            131
# 64823   9781593080150              2003     24217           2403
# 68929   9780451520081              1960   1553094             16
# 74630   9788420691732              2010   8174919             28
# 81630   9780451523204              1960     17723            260
# 90587   9780831766948              1996   1128181             36
# 95141                              1974  11038457             39
# 95734   9781587265327              2003   6225724             38
# 98671   9788073095239              2007  10366450             31
# 99117   9780563536857              2002  21079595              4
# 102094  9781840813524              1999    426802             25
# 104156  9788497897013              2008   3805146             35
# 106009  9782070389162              1994   1372187            126
# 108990  9780307290878              2008   6618326            188
# 114315                             1998   9535903             10
# 117691  9780760716199              1993    562849            347
# 119646                             2007  22853125             62
# 121850  9781560772606              1992    426808              6
# 123198  9781853261183              1993   6575942            242
#
#                                                     title
# 223     Alice's Adventures in Wonderland & Through the...
# 4018    Alice In Wonderland and Through the Looking-glass
# 4491    Alice's Adventures in Wonderland & Through the...
# 6108    Alice's Adventures in Wonderland & Through the...
# 6316    Aventuras De Alicia En El País De Las Maravill...
# 8231    Alicia en el País de las Maravillas & A través...
# 9324      Alice in Wonderland & Through the Looking Glass
# 19874   Alice's Adventures in Wonderland & Through the...
# 25165   Alice's Adventures in Wonderland and Through t...
# 30876   Le avventure di Alice nel paese delle meravigl...
# 33047   Alice's Adventures In Wonderland and Through t...
# 37221   Alice's Adventures In Wonderland And Through T...
# 40536     Alice In Wonderland & Through The Looking Glass
# 40537   Alice In Wonderland And Through The Looking Glass
# 42332   Alice in Wonderland and Through the Looking Glass
# 42483     Alice in Wonderland & Through the Looking Glass
# 56167   Alice's Adventures in Wonderland & Through the...
# 59084   Le Avventure di Alice nel Paese delle Meravigl...
# 62951   Alice's Adventures in Wonderland and Through t...
# 64557   Alice in Wonderland and Through the Looking Glass
# 64823   Alice's Adventures in Wonderland and Through t...
# 68929   Alice's Adventures in Wonderland & Through the...
# 74630   Alicia en el País de las Maravillas - Alicia a...
# 81630   Alice's Adventures in Wonderland/Through the L...
# 90587     Alice In Wonderland / Through The Looking Glass
# 95141   Liisan seikkailut ihmemaassa ja Liisan seikkai...
# 95734   Alice's Adventures in Wonderland and Through t...
# 98671                  Alenka v kraji divů… a za zrcadlem
# 99117      Alice In Wonderland  Through The Looking Glass
# 102094  Alice's Adventures in Wonderland & Through the...
# 104156  Alice's Adventures in Wonderland & Through the...
# 106009  Alice au pays des merveilles / De l'autre côté...
# 108990  Alice's Adventure in Wonderland and Through th...
# 114315  Alice's Adventures in Wonderland; Through the ...
# 117691  Alice in Wonderland and Through the Looking Glass
# 119646  Alice's Adventures in Wonderland and Through t...
# 121850  Alice's Adventures in Wonderland/Through the L...
# 123198  Alice in Wonderland and Through the Looking Glass

# %% [markdown]
# #### Language_code

# %% [markdown]
# There are 90 unique values in the language code variable, but for the majority of books, this value is a white space. There are also 2 books with -- as language category, and one book with pt-Br instead of por (for portuguese). English have also different codes, like en-Us, en-GB, eng-Ca or eng.
# In this case, we are just interested in books written or translated to english language. So we will check carefully the books descriptions using the langdetect function, and we will delete the books in which the language code is different than english or if the descriptions are written in another different language.

# %%
books1.language_code.value_counts()
# Out:
#          54429
# eng      20893
# en-US     4728
# en-GB     1284
# spa       1023
# ind        833
# fin        817
# ita        699
# ger        669
# nl         634
# por        567
# fre        494
# swe        443
# per        254
# bul        237
# tur        212
# gre        208
# cze        194
# dan        191
# ara        167
# nor        162
# rum        149
# pol        122
# rus        112
# est         90
# lav         83
# vie         79
# slo         65
# scr         55
# hun         54
# ukr         51
# ben         48
# en-CA       44
# nob         43
# lit         40
# mul         25
# kat         24
# srp         23
# fil         22
# tha         17
# zho         17
# jpn         16
# cat         14
# afr         12
# msa         10
# pes         10
# hye          6
# slv          6
# tgl          5
# kor          5
# isl          5
# lat          5
# mal          4
# sin          4
# nno          3
# nav          2
# --           2
# bos          2
# gle          2
# heb          2
# glg          2
# sco          2
# egy          1
# smn          1
# mlt          1
# eus          1
# hin          1
# mkd          1
# nub          1
# sqi          1
# mon          1
# fao          1
# hmn          1
# yid          1
# pt-BR        1
# kaz          1
# dum          1
# oci          1
# nld          1
# krl          1
# roh          1
# guj          1
# Name: language_code, dtype: int64

# %%
books1[books1.language_code == '--']
# Out:
#               isbn  text_reviews_count language_code is_ebook  average_rating  \
# 108770  3785544359                   2            --    false            4.15
# 122588                               1            --    false            4.28
#
#                                               description     format  \
# 108770  As a child, there are constantly people trying...  Hardcover
# 122588  Translated to Spanglish by Ilan Stavans, this ...  Paperback
#
#                  publisher num_pages         isbn13  publication_year  \
# 108770               Loewe        32  9783785544358              2002
# 122588  Edition Tintenfass        96  9783946190431              2016
#
#          book_id  ratings_count  \
# 108770   7940220              6
# 122588  34369354              1
#
#                                                     title
# 108770  Mein Körper gehört mir! Schutz vor Missbrauch ...
# 122588                                 El Little Principe

# %% [markdown]
# There is one book written in spanglish and a book written in german. So we will delete these two rows.

# %%
books1.drop(books1[books1.language_code == '--'].index, inplace=True)

# %%
#Let's replace the english variants for just eng.
books1.language_code.replace({"": "unknown", 'en-US':'eng', 'en-GB':'eng', 'en-CA':'eng'}, inplace=True)

# %%
books1.language_code.unique()
# Out:
# array(['unknown', 'eng', 'fin', 'scr', 'fil', 'ger', 'tur', 'ara', 'nl',
#        'gre', 'zho', 'est', 'spa', 'fre', 'dan', 'cze', 'per', 'ind',
#        'rum', 'ita', 'por', 'ben', 'swe', 'nor', 'vie', 'hun', 'rus',
#        'lit', 'bul', 'mul', 'slo', 'pol', 'ukr', 'nob', 'pes', 'lav',
#        'cat', 'smn', 'mal', 'kat', 'srp', 'jpn', 'slv', 'oci', 'pt-BR',
#        'kor', 'afr', 'tha', 'msa', 'lat', 'tgl', 'sin', 'mon', 'mlt',
#        'gle', 'egy', 'glg', 'hye', 'isl', 'sqi', 'dum', 'yid', 'guj',
#        'sco', 'fao', 'bos', 'heb', 'eus', 'hmn', 'nav', 'mkd', 'nld',
#        'hin', 'kaz', 'krl', 'roh', 'nno', 'nub'], dtype=object)

# %%
#Let's check some language_codes to see the titles and descriptions.
books1[books1.language_code == 'scr'].sample(10)
# Out:
#               isbn  text_reviews_count language_code is_ebook  average_rating  \
# 60471   9532130195                   1           scr    false            4.28
# 111365  9532290451                   3           scr    false            3.05
# 18375                                1           scr    false            3.53
# 102765  953612498X                   3           scr    false            4.09
# 10010   9533240482                   6           scr    false            3.88
# 25                                   1           scr    false            3.92
# 50722   9531967075                   4           scr    false            3.80
# 2360    9536989077                   8           scr    false            4.28
# 111204  9531969744                   8           scr    false            3.63
# 48240                                5           scr    false            4.24
#
#                                               description  \
# 60471   Le Petit Princ (Mali princ, 1943. godine), dje...
# 111365  Kraj u kojemu smo rodeni i u kojemu smo odrast...
# 18375   Lili obozava carobirati, sve od trenutka kad j...
# 102765  Nenadani susret sestara blizanki u ljetovalist...
# 10010   Roman Sofijin svijet nastao je iz Gaarderove z...
# 25      Nakon Labirinta kostiju u kojem je sve pocelo,...
# 50722   Vladimir Nazor nas u BIJELOM JELENU uvodi u ba...
# 2360    Prica o WAITAPU zapravo je poetska bajka o pot...
# 111204  Novo izdanje pripovjedaka Dinka Simunovica, sa...
# 48240   Kad bismo pokusali odrediti zanr romana Demon ...
#
#                        format              publisher num_pages         isbn13  \
# 60471               Hardcover          Marjan knjiga       104
# 111365              Hardcover                    ABC       125
# 18375               Hardcover          Mozaik knjiga       132  9789531407267
# 102765              Hardcover         Znanje, Zagreb       114  9789536124985
# 10010   Mass Market Paperback  Znanje d.o.o., Zagreb       512  9789533240480
# 25                  Hardcover              Algoritam       208  9789533164069
# 50722               Paperback          Mozaik knjiga        84
# 2360                Hardcover         Neretva d.o.o.       162
# 111204              Hardcover   Mozaik knjiga d.o.o.       197
# 48240               Hardcover              Algoritam       220  9789533168241
#
#         publication_year   book_id  ratings_count  \
# 60471               2000  12396588             36
# 111365              2005   9841888             64
# 18375               2010  31868708              1
# 102765              1995  12475550             65
# 10010               2010  10652799            106
# 25                  2011  25208148              7
# 50722               2000  10756509            333
# 2360                1993   8423233            131
# 111204              2002   8981458            770
# 48240               2015  25665932             26
#
#                                                     title
# 60471                                          Mali princ
# 111365                          Voda i druge pripovijetke
# 18375   Čarobnica Lili leti na Mjesec (Čarobnica Lili,...
# 102765                                           Blizanke
# 10010                                      Sofijin svijet
# 25                          Kao u grobu (39 tragova,  #4)
# 50722                                        Bijeli jelen
# 2360                                              Waitapu
# 111204                                               Duga
# 48240                             Demon školske knjižnice

# %%
#And the books with unknown language code. We can see many of them are written in english.
books1[books1.language_code == 'unknown'].sample(30)
# Out:
#               isbn  text_reviews_count language_code is_ebook  average_rating  \
# 38980   0192727745                   2       unknown    false            4.25
# 109005  0310727308                   8       unknown    false            4.06
# 121682  0395687004                   7       unknown    false            3.69
# 1074    0061853089                   2       unknown    false            4.27
# 108257  0544022637                  12       unknown    false            3.90
# 55161   0064442950                   4       unknown    false            4.12
# 102062  0552547123                  21       unknown    false            3.81
# 104102  0060239824                  19       unknown    false            3.67
# 86881   0761320776                   3       unknown    false            3.06
# 89865   079452852X                   2       unknown    false            3.29
# 66995   161599002X                   4       unknown    false            4.75
# 7151    0340656743                   1       unknown    false            4.29
# 108247  0516245678                   2       unknown    false            3.50
# 123259  1862057710                  23       unknown    false            3.85
# 30771   0881490075                   3       unknown    false            3.91
# 1513    1410308596                   1       unknown     true            4.20
# 78368   0761328742                  10       unknown    false            4.10
# 51427   013218933X                   2       unknown    false            3.90
# 76226   0395941490                   2       unknown    false            3.71
# 115855  1605371033                   6       unknown    false            3.45
# 35686   0375964584                  28       unknown    false            4.03
# 44748   0778707466                   1       unknown    false            3.00
# 93303   1634460049                   1       unknown    false            4.45
# 21023   074456056X                  13       unknown    false            3.63
# 110617  014050723X                   3       unknown    false            4.22
# 43262   0794423469                   3       unknown    false            3.85
# 101439  0395554403                   1       unknown    false            3.67
# 21416   1511958448                   9       unknown    false            4.44
# 55529   0394985702                  20       unknown    false            3.95
# 106903  1433506017                  32       unknown    false            4.22
#
#                                               description           format  \
# 38980   I fjarde vaningen i ett hyreshus nagonstans i ...        Paperback
# 109005  A Lesson in Being Patient\nThe Pod Squad needs...        Paperback
# 121682  Rabbit leaves her warm dark burrow and discove...        Hardcover
# 1074    Braaaaains \nZack Clarke, his best pal, Rice, ...        Paperback
# 108257  In Chinese, peng youmeans friend. But in any l...        Paperback
# 55161   Rain-day bluesJohnny Lion has everything he ne...        Paperback
# 102062  Fortunately for Jacqueline Wilson fans, her ne...        Paperback
# 104102  Thirty-eight original limericks about all mann...        Hardcover
# 86881   A young girl camps out in her bedroom and is j...        Paperback
# 89865   Babies will love sharing this book with you. T...       Board Book
# 66995   Many children are gifted in the psychic area, ...        Paperback
# 7151    A little creature lies in the attic forgotten,...        Paperback
# 108247  NATIONAL STANDARDS: Grades K-4 National Social...        Hardcover
# 123259  Every dish in this very unique cookbook has on...        Hardcover
# 30771   Help Me Be Good About Throwing Tantrums explai...        Hardcover
# 1513    This charming tale of an overgrown pine always...            ebook
# 78368   There are many, many kinds of art. Citing work...        Hardcover
# 51427        A pet's eye view of life with Count Dracula.  Unknown Binding
# 76226   Images of sleep and images of the ocean meet i...        Hardcover
# 115855  Ian's mom buys him new 'big boy' underpants an...        Hardcover
# 35686   Verses inspired by Camille Saint-Sa'ens' The c...        Hardcover
# 44748   Describes the many struggles slaves faced duri...        Hardcover
# 93303   What do Adam and Jesus have in common? What do...        Hardcover
# 21023   Pip is a playful, three-year-old Adelie pengui...  Unknown Binding
# 110617  When three Christmas Eve wishes are made, some...        Paperback
# 43262   Halloween is full of fun and surprises when th...       Board Book
# 101439  Picked on at school by bullies, thirteen-year-...        Hardcover
# 21416   There are hundreds or maybe even thousands of ...        Paperback
# 55529   With the new school counselor's help, Bradley ...  Library Binding
# 106903  Equips parents to guide their young children t...        Paperback
#
#                                           publisher num_pages         isbn13  \
# 38980                  Oxford University Press, USA       183  9780192727749
# 109005                                   Zonderkidz        32  9780310727309
# 121682                                Clarion Books        32  9780395687000
# 1074                                  HarperCollins       204  9780061853081
# 108257                  HMH Books for Young Readers       160  9780544022638
# 55161                                 HarperCollins        64  9780064442954
# 102062                              Corgi Childrens       288  9780552547123
# 104102                     HarperCollins Publishers        48  9780060239824
# 86881                               Millbrook Press        28  9780761320777
# 89865                                 Usborne Books        10  9780794528522
# 66995                        Marvelous Spirit Press        20  9781615990023
# 7151                                      Not Avail        32  9780340656747
# 108247                         Children's Press(CT)        32  9780516245676
# 123259                                     Pavilion        80  9781862057715
# 30771                                                          9780881490077
# 1513                            Sleeping Bear Press        20  9781410308597
# 78368                               Millbrook Press        32  9780761328742
# 51427                                 Prentice Hall            9780132189330
# 76226                                 Clarion Books        32  9780395941492
# 115855                                       Clavis        32  9781605371030
# 35686                 Knopf Books for Young Readers        40  9780375964589
# 44748                   Crabtree Publishing Company        32  9780778707462
# 93303                        Emmaus Road Publishing        26  9781634460040
# 21023                                     Not Avail        25  9780744560565
# 110617                                       Puffin        32  9780140507232
# 43262                      Studio Fun International        10  9780794423469
# 101439                                Clarion Books       176  9780395554401
# 21416   Createspace Independent Publishing Platform        50  9781511958448
# 55529                 Knopf Books for Young Readers       208  9780394985701
# 106903                               Crossway Books       234  9781433506017
#
#         publication_year   book_id  ratings_count  \
# 38980               2009   6338700             53
# 109005              2011  11262145             25
# 121682              1995   4052958             35
# 1074                2011  10905281             25
# 108257              2013  15814549             65
# 55161               2000   1402954             31
# 102062              2004   1527197            240
# 104102              1983    311794             64
# 86881               1999   2973608             16
# 89865               2010  11480634              7
# 66995               2009   7137812              4
# 7151                1996   6865289             13
# 108247              2005   4708476             13
# 123259              2009   4758774             64
# 30771               1988   1039567             33
# 1513                2011  23221266              1
# 78368               2003   6218029             39
# 51427               1978   4183731             10
# 76226               1999    952041              7
# 115855              2011  12861782             53
# 35686               2010   7819561             95
# 44748               2001   3541715              1
# 93303               2014  25252052              2
# 21023               1997   2597908             42
# 110617              1987   1766458             21
# 43262               2011  11792614             39
# 101439              1991   4892516              8
# 21416               2015  26338865             14
# 55529               1987    527303            154
# 106903              2009   6414162            353
#
#                                                     title
# 38980                Karlson Flies Again. Astrid Lindgren
# 109005  Bob and Larry in the Case of the Missing Patience
# 121682                                 Rabbit's Good News
# 1074                 Undead Ahead (The Zombie Chasers #2)
# 108257                               The Year of the Book
# 55161                          Johnny Lion's Rubber Boots
# 102062                                          Lola Rose
# 104102               The Book of Pigericks: Pig Limericks
# 86881                                         My Camp-Out
# 89865       Baby's Very First Touchy-Feely Christmas Book
# 66995     Jamie and the Angel: Meeting Her Guardian Angel
# 7151                                              Nothing
# 108247                                         Rude Ralph
# 123259         How to Cook Children: A Grisly Recipe Book
# 30771                                   Throwing Tantrums
# 1513                        A Wish to Be a Christmas Tree
# 78368                                           Art Is...
# 51427                                       Dracula's Cat
# 76226   Fishing for a Dream: Ocean Lullabies and Night...
# 115855                                    Ian's New Potty
# 35686                         The Carnival of the Animals
# 44748                                      A Slave Family
# 93303   The End of the Fiery Sword: Adam & Eve and Jes...
# 21023                                      Little Penguin
# 110617                         The Story of Holly and Ivy
# 43262       Fisher Price Little People Halloween is Here!
# 101439                                       Face to Face
# 21416     123 Count with Me: Fun with Numbers and Animals
# 55529                There's a Boy in the Girls' Bathroom
# 106903  Big Truths for Young Hearts: Teaching and Lear...

# %% [markdown]
# Before detecting the language of the descriptions, we have to lowercase them. We will create a new column with all the descriptions transformed to lowercase.

# %%
def preprocess_df(df):
    
    def process_string(x):
                 
        x = x.lower()
        return x
     
    df['descriptiondetect'] = df['description'].apply(process_string)
    
    return df

# %%
# %%time
books2=preprocess_df(books1)
# Out:
# Wall time: 136 ms

# %%
books2.descriptiondetect
# Out:
# 0         relates in vigorous prose the tale of aeneas, ...
# 1         to kara's astonishment, she discovers that a p...
# 2         in newbery medalist cynthia rylant's classic b...
# 4         what do you do?\na hen lays eggs...\na cow giv...
# 5         ben draws a train that takes him to all sorts ...
#                                 ...
# 124075    holy unanticipated occurrences! a cynic meets ...
# 124076    rhyming text and illustrations of comical cats...
# 124079    "a perfect reminder to always be on the lookou...
# 124080    one of the most popular series ever published ...
# 124081    gathers poems by william blake, emily bronte, ...
# Name: descriptiondetect, Length: 90438, dtype: object

# %%
books2.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'language_code', 'is_ebook',
#        'average_rating', 'description', 'format', 'publisher', 'num_pages',
#        'isbn13', 'publication_year', 'book_id', 'ratings_count', 'title',
#        'descriptiondetect'],
#       dtype='object')

# %% [markdown]
# And now we will use the detect_langs function to check all descriptions, creating a new column to keep all the results.

# %% [markdown]
# ''' Important!!!
# It takes a long time to run the cell below, so I have kept it in markdown format.
# The dataset with the new column has been saved as a csv file, we have just to import it to keep working on the project
# instead of run it every time we restart the kernel'''

# %% [markdown]
# %%time
# from langdetect import detect_langs
#
# languages = []
#
# for row in range(len(books2)):
#     try:
#         languages.append(detect_langs(books2.iloc[row,14]))
#
#     except:
#         languages.append('?')
#
# languages = [str(lang).split(':')[0][1:] for lang in languages]
#
# books2['detect']=languages
# print(books2.head())

# %% [markdown]
# books2[books2.language_code=='unknown'].detect.value_counts()

# %% [markdown]
# As the language detection takes a long time to run, let's save the dataset with the results in a new csv and let's import it again so we don't have to run it every time we restart the kernel.

# %% [raw]
# #Important!!!
# #Don't run this cell in order to avoid overwritting the csv file.
# file_name='booksdescriptiondetect.csv'
# books2.to_csv(file_name, index=False)

# %% [markdown]
# ##### Importing the clean csv file

# %%
books = pd.read_csv('booksdescriptiondetect.csv')

# %%
books.head(2)
# Out:
#          isbn  text_reviews_count language_code  is_ebook  average_rating  \
# 0  1599150603                   7       unknown     False            4.13
# 1  1934876569                   6       unknown     False            4.22
#
#                                          description     format  \
# 0  Relates in vigorous prose the tale of Aeneas, ...  Paperback
# 1  To Kara's astonishment, she discovers that a p...  Paperback
#
#               publisher  num_pages         isbn13  publication_year  book_id  \
# 0  Yesterday's Classics      162.0  9781599150604              2006   287141
# 1            Seven Seas      216.0  9781934876565              2009  6066812
#
#    ratings_count                                              title  \
# 0             46                      The Aeneid for Boys and Girls
# 1             98  All's Fairy in Love and War (Avalon: Web of Ma...
#
#                                    descriptiondetect detect
# 0  relates in vigorous prose the tale of aeneas, ...     en
# 1  to kara's astonishment, she discovers that a p...     en

# %%
books.shape
# Out:
# (90438, 16)

# %%
books.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'language_code', 'is_ebook',
#        'average_rating', 'description', 'format', 'publisher', 'num_pages',
#        'isbn13', 'publication_year', 'book_id', 'ratings_count', 'title',
#        'descriptiondetect', 'detect'],
#       dtype='object')

# %%
books_otherlang=books[(books.language_code != 'unknown') & (books.language_code != 'eng') ]

# %%
books_otherlang[books_otherlang.detect=='es']  
#checking if the detection looks correct in different language codes.It looks correct, so let's drop the rows matching those conditions.
# Out:
#              isbn  text_reviews_count language_code  is_ebook  average_rating  \
# 165    8416690073                   6           spa     False            4.05
# 217    8714193523                   7           dan     False            3.88
# 283    8498676185                   1           spa     False            4.27
# 608    844066785X                   2           spa     False            3.51
# 639           NaN                   1           spa     False            4.08
# ...           ...                 ...           ...       ...             ...
# 89933  8422610086                   6           spa     False            4.29
# 89997  842644556X                   4           spa     False            3.89
# 90212         NaN                   1           spa     False            3.88
# 90373  8494411039                  13           spa     False            3.88
# 90390  9788496886                   9           spa     False            3.95
#
#                                              description     format  \
# 165    Suzy Swanson esta segura de que conoce el verd...  Paperback
# 217    Luego del exito mundial del libro que relata l...  Paperback
# 283    "A las mellizas les parecio que el tren tardab...  Paperback
# 608    Zakie Beauchamp quiere convertirse en un famos...  Paperback
# 639    La ciudad en verano es el campo de juego perfe...  Hardcover
# ...                                                  ...        ...
# 89933  en una ciudad -cualquier ciudad- aparece un di...  Hardcover
# 89997  Enviamos un dibijo de Quint a cuarenta y seis ...  Hardcover
# 90212  Con el unico objeto de divertir a una nina de ...  Paperback
# 90373  Buenas noches, Charlie,\ndulces suenos, Jack.\...  Hardcover
# 90390  Un debut maravilloso destinado a convertirse e...  Paperback
#
#                     publisher  num_pages         isbn13  publication_year  \
# 165                     Maeva      320.0  9788416690077              2016
# 217                Host & Son      542.0  9788714193522              1995
# 283                    Molino        NaN  9788498676181              2009
# 608               Ediciones B      140.0  9788440667854              1999
# 639             Barbara Fiore       48.0  9788415208464              2014
# ...                       ...        ...            ...               ...
# 89933     circulo de lectores      232.0            NaN              1988
# 89997                   Lumen      120.0  9788426445568              1998
# 90212                     ERA       52.0  9786074554564              2010
# 90373  Oceano - Gran Travesia      403.0  9788494411038              2015
# 90390          Editorial Puck      320.0            NaN              2016
#
#         book_id  ratings_count  \
# 165    32792284             17
# 217     8285950            267
# 283    11196995             29
# 608    17610045              9
# 639    22066825             17
# ...         ...            ...
# 89933   2799598             29
# 89997    993956             14
# 90212  30347070              3
# 90373  26239341             26
# 90390  28592527             19
#
#                                                    title  \
# 165                         Lo que sucedió con la medusa
# 217                                        Sofies verden
# 283     Santa Clara: Todos los cursos (St. Clare's #1-6)
# 608                 El monstruo baboso (Pesadillas, #53)
# 639                                Las reglas del verano
# ...                                                  ...
# 89933                                               Momo
# 89997  El Libro De Los Libros. Historias sobre imágenes.
# 90212                                  Alicia para niños
# 90373                     ¡Pesadillas! (¡Pesadillas! #1)
# 90390                      El Reino de las Posibilidades
#
#                                        descriptiondetect detect
# 165    suzy swanson esta segura de que conoce el verd...     es
# 217    luego del exito mundial del libro que relata l...     es
# 283    "a las mellizas les parecio que el tren tardab...     es
# 608    zakie beauchamp quiere convertirse en un famos...     es
# 639    la ciudad en verano es el campo de juego perfe...     es
# ...                                                  ...    ...
# 89933  en una ciudad -cualquier ciudad- aparece un di...     es
# 89997  enviamos un dibijo de quint a cuarenta y seis ...     es
# 90212  con el unico objeto de divertir a una nina de ...     es
# 90373  buenas noches, charlie,\ndulces suenos, jack.\...     es
# 90390  un debut maravilloso destinado a convertirse e...     es
#
# [799 rows x 16 columns]

# %%
books.drop(books[(books.language_code != 'unknown') & (books.language_code != 'eng') ].index, inplace = True)

# %%
books.language_code.unique()
# Out:
# array(['unknown', 'eng'], dtype=object)

# %%
books.shape
# Out:
# (81378, 16)

# %%
books_eng=books[books.language_code=='eng']

# %%
books_eng.detect.value_counts()
# Out:
# en    26771
# es       32
# fr       20
# de       16
# id       14
# nl       13
# hr       12
# it        9
# pt        8
# no        7
# af        6
# tl        6
# sv        5
# cy        5
# ca        5
# pl        4
# da        3
# sl        3
# sk        2
# fi        2
# lt        2
# sq        1
# cs        1
# et        1
# tr        1
# Name: detect, dtype: int64

# %% [markdown]
# We can see that there are books with eng as language code where the descriptions are detected as other different languages.
# Let's check them

# %%
#books_eng[books_eng.detect=='es']
#books_eng[books_eng.detect=='fr']

# %%
#Let's keep just the books with english language_code where the description language detection was english.
books.drop(books[(books.language_code == 'eng') & (books.detect != 'en') ].index, inplace = True)

# %%
books[books.language_code=='eng'].detect.value_counts()
# Out:
# en    26771
# Name: detect, dtype: int64

# %%
books[books.language_code=='unknown'].detect.value_counts()
# Out:
# en    53889
# es      174
# fr       90
# id       42
# cy       28
# de       27
# sv       22
# nl       21
# fi       20
# it       18
# pt       16
# da       13
# af        9
# hr        9
# sl        7
# no        7
# pl        5
# ro        5
# tr        5
# vi        4
# sw        4
# tl        3
# sk        2
# hu        2
# ca        2
# cs        1
# sq        1
# so        1
# lt        1
# Name: detect, dtype: int64

# %%
books_unk=books[books.language_code=='unknown']

# %%
#books_unk[books_unk.detect=='es']
books_unk[books_unk.detect=='en']
#The detection language looks fine inside the unknown language codes as well in most of the cases.
# Out:
#              isbn  text_reviews_count language_code  is_ebook  average_rating  \
# 0      1599150603                   7       unknown     False            4.13
# 1      1934876569                   6       unknown     False            4.22
# 3      1416904999                   4       unknown     False            3.57
# 4      0531301060                   3       unknown     False            3.68
# 5      0884482987                  17       unknown     False            3.89
# ...           ...                 ...           ...       ...             ...
# 90432  055256916X                  16       unknown     False            4.11
# 90434  1575054035                  36       unknown     False            4.05
# 90435  0061960314                  13       unknown     False            4.29
# 90436  0689852959                   1       unknown     False            4.36
# 90437  0765197456                   6       unknown     False            4.00
#
#                                              description      format  \
# 0      Relates in vigorous prose the tale of Aeneas, ...   Paperback
# 1      To Kara's astonishment, she discovers that a p...   Paperback
# 3      WHAT DO YOU DO?\nA hen lays eggs...\nA cow giv...  Board Book
# 4      Ben draws a train that takes him to all sorts ...   Hardcover
# 5      When Amadi disobeys his mother and runs off to...   Hardcover
# ...                                                  ...         ...
# 90432  When they first arrived, they came quietly and...   Paperback
# 90434  Rhyming text and illustrations of comical cats...   Hardcover
# 90435  "A perfect reminder to always be on the lookou...   Hardcover
# 90436  One of the most popular series ever published ...   Paperback
# 90437  Gathers poems by William Blake, Emily Bronte, ...   Hardcover
#
#                       publisher  num_pages         isbn13  publication_year  \
# 0          Yesterday's Classics      162.0  9781599150604              2006
# 1                    Seven Seas      216.0  9781934876565              2009
# 3                  Little Simon       24.0  9781416904991              2005
# 4            Orchard Books (NY)        NaN  9780531301067              1999
# 5      Tilbury House Publishers       32.0  9780884482987              2008
# ...                         ...        ...            ...               ...
# 90432           Corgi Childrens      336.0  9780552569163              2015
# 90434          Carolrhoda Books        NaN  9781575054032              2000
# 90435             HarperCollins       40.0  9780061960314              2010
# 90436                   Aladdin      176.0  9780689852954              2002
# 90437      Smithmark Publishers       96.0  9780765197450              1996
#
#         book_id  ratings_count  \
# 0        287141             46
# 1       6066812             98
# 3       1698376             23
# 4       2592648             21
# 5       3631900             44
# ...         ...            ...
# 90432  23346344             58
# 90434    823094            240
# 90435   7925060             40
# 90436    331839             18
# 90437   2342551             36
#
#                                                    title  \
# 0                          The Aeneid for Boys and Girls
# 1      All's Fairy in Love and War (Avalon: Web of Ma...
# 3                                        What Do You Do?
# 4                 It's Funny Where Ben's Train Takes Him
# 5                    Amadi's Snowman: A Story of Reading
# ...                                                  ...
# 90432                                   Boy In The Tower
# 90434                     To Root, to Toot, to Parachute
# 90435                                       Instructions
# 90436     Jacqueline Kennedy Onassis: Friend of the Arts
# 90437           The Children's Classic Poetry Collection
#
#                                        descriptiondetect detect
# 0      relates in vigorous prose the tale of aeneas, ...     en
# 1      to kara's astonishment, she discovers that a p...     en
# 3      what do you do?\na hen lays eggs...\na cow giv...     en
# 4      ben draws a train that takes him to all sorts ...     en
# 5      when amadi disobeys his mother and runs off to...     en
# ...                                                  ...    ...
# 90432  when they first arrived, they came quietly and...     en
# 90434  rhyming text and illustrations of comical cats...     en
# 90435  "a perfect reminder to always be on the lookou...     en
# 90436  one of the most popular series ever published ...     en
# 90437  gathers poems by william blake, emily bronte, ...     en
#
# [53889 rows x 16 columns]

# %%
books.shape
# Out:
# (81200, 16)

# %%
#Let's keep just the unknown books where the description language detection was english.
books.drop(books[(books.language_code == 'unknown') & (books.detect != 'en') ].index, inplace = True)

# %%
books.shape
# Out:
# (80660, 16)

# %%
books[books.language_code=='unknown'].detect.value_counts()
# Out:
# en    53889
# Name: detect, dtype: int64

# %%
books.language_code.isnull().sum()
# Out:
# 0

# %%
books.language_code.value_counts()
# Out:
# unknown    53889
# eng        26771
# Name: language_code, dtype: int64

# %%
books.detect.value_counts()
# Out:
# en    80660
# Name: detect, dtype: int64

# %%
books.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'language_code', 'is_ebook',
#        'average_rating', 'description', 'format', 'publisher', 'num_pages',
#        'isbn13', 'publication_year', 'book_id', 'ratings_count', 'title',
#        'descriptiondetect', 'detect'],
#       dtype='object')

# %%
#Now that all books have english as language_code, let's drop the columns language_code and detect.
books=books.drop(['language_code', 'detect'],axis=1)

# %%
books.shape
# Out:
# (80660, 14)

# %% [markdown]
# ##### Dealing with missing values

# %% [markdown]
# After importing the books.csv, the whitespaces have been replaced by NaN values. So we will use the function isnull to check the rest of the columns.

# %%
books.isnull().sum()
# Out:
# isbn                  1889
# text_reviews_count       0
# is_ebook                 0
# average_rating           0
# description              0
# format                1356
# publisher              924
# num_pages             7737
# isbn13                 469
# publication_year         0
# book_id                  0
# ratings_count            0
# title                    1
# descriptiondetect        0
# dtype: int64

# %% [markdown]
# #### Titles

# %%
books.title.isnull().sum()
# Out:
# 1

# %%
# Let's check the book with the missing title
books[books.title.isna()]
# Out:
#              isbn  text_reviews_count  is_ebook  average_rating  \
# 34303  0440428475                   3     False            3.63
#
#                                              description     format publisher  \
# 34303  Ben has always been content to be brilliant at...  Paperback  Yearling
#
#        num_pages         isbn13  publication_year  book_id  ratings_count  \
# 34303      160.0  9780440428473              1985  2433394              8
#
#       title                                  descriptiondetect
# 34303   NaN  ben has always been content to be brilliant at...

# %% [markdown]
# https://www.goodreads.com/book/show/2433394

# %%
#Let's add manually the title
books.title= books.title.fillna('(George)')

# %%
books.title.isnull().sum()
# Out:
# 0

# %%
books.title.value_counts()
# Out:
# The Secret Garden                                         99
# Peter Pan                                                 88
# The Wind in the Willows                                   82
# Alice's Adventures in Wonderland                          74
# Anne of Green Gables                                      72
#                                                           ..
# Charlie Chick Wants to Play                                1
# She Persisted: 13 American Women Who Changed the World     1
# Big Bad Detective Agency - Library Edition                 1
# Nobody Has Time for Me                                     1
# The Adventures of Isaiah James: Beach Boy                  1
# Name: title, Length: 64916, dtype: int64

# %% [markdown]
# Let's try to detect if there are titles not written in English but having a description in English.

# %%
def preprocess_df(df):
    
    def process_string(x):
                 
        x = x.lower()
        return x
     
    df['titledetect'] = df['title'].apply(process_string)
    
    return df

# %%
books=preprocess_df(books)

# %%
books.titledetect
# Out:
# 0                            the aeneid for boys and girls
# 1        all's fairy in love and war (avalon: web of ma...
# 2                                               dog heaven
# 3                                          what do you do?
# 4                   it's funny where ben's train takes him
#                                ...
# 90433        flora and ulysses: the illuminated adventures
# 90434                       to root, to toot, to parachute
# 90435                                         instructions
# 90436       jacqueline kennedy onassis: friend of the arts
# 90437             the children's classic poetry collection
# Name: titledetect, Length: 80660, dtype: object

# %%
books.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'is_ebook', 'average_rating',
#        'description', 'format', 'publisher', 'num_pages', 'isbn13',
#        'publication_year', 'book_id', 'ratings_count', 'title',
#        'descriptiondetect', 'titledetect'],
#       dtype='object')

# %% [markdown]
# Again, don't run the cell below at it takes a long time, the dataset with the results of
# applying langdetect function are saved in the csv file 'bookstitledetect.csv'

# %% [raw]
# #### Important don't run this cell as it takes a long time!!!!
#
#
# %%time
# from langdetect import detect_langs
#
# languages = []
#
# for row in range(len(books)):
#     try:
#         languages.append(detect_langs(books.iloc[row,14]))
#
#     except:
#         languages.append('?')
#
# languages = [str(lang).split(':')[0][1:] for lang in languages]
#
# books['detect_tit']=languages
# print(books.head())

# %%
books.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'is_ebook', 'average_rating',
#        'description', 'format', 'publisher', 'num_pages', 'isbn13',
#        'publication_year', 'book_id', 'ratings_count', 'title',
#        'descriptiondetect', 'titledetect'],
#       dtype='object')

# %% [raw]
# #Important!!!  Don't run this cell in order to avoid overwritting
# file_name='bookstitledetect.csv'
# books.to_csv(file_name, index=False)

# %% [markdown]
# ####  Importing the clean csv file with the detected language of the titles

# %%
books = pd.read_csv('bookstitledetect.csv')

# %%
books.detect_tit.value_counts()
# Out:
# en    59770
# af     1994
# cy     1645
# it     1490
# da     1430
# no     1382
# fr     1370
# tl     1193
# nl     1072
# so      930
# ca      927
# ro      729
# id      698
# es      688
# et      659
# sv      591
# fi      588
# pl      485
# pt      373
# sk      349
# de      319
# tr      291
# lt      291
# hr      253
# cs      232
# sl      215
# sq      212
# sw      181
# hu      122
# lv      106
# vi       55
# fa        6
# ar        5
# ja        2
# bg        1
# ko        1
# Name: detect_tit, dtype: int64

# %%
books[books.detect_tit=='ko']  #try also with bg, ja,ar, fa all are titles in different languages than english.
# Out:
#              isbn  text_reviews_count  is_ebook  average_rating  \
# 51712  8983782706                   2     False            3.88
#
#                                              description     format  \
# 51712  THIS JUST IN! Amy and Dan Cahill were spotted ...  Paperback
#
#           publisher  num_pages         isbn13  publication_year  book_id  \
# 51712  Seoul Gyoyuk      264.0  9788983782700              2010  8907049
#
#        ratings_count                 title  \
# 51712             25  모차르트의 악보 (39 클루스. 2)
#
#                                        descriptiondetect  \
# 51712  this just in! amy and dan cahill were spotted ...
#
#                 titledetect detect_tit
# 51712  모차르트의 악보 (39 클루스. 2)         ko

# %%
books.detect_tit.unique()
# Out:
# array(['en', 'da', 'pt', 'af', 'id', 'es', 'sw', 'pl', 'fi', 'sv', 'nl',
#        'et', 'fr', 'so', 'tl', 'sk', 'vi', 'it', 'ro', 'ca', 'hr', 'lt',
#        'tr', 'cy', 'no', 'de', 'cs', 'sq', 'hu', 'lv', 'sl', 'fa', 'ar',
#        nan, 'ja', 'ko', 'bg'], dtype=object)

# %%
books.detect_tit.replace({'ko':'del', 'ja':'del', 'ar': 'del', 'fa': 'del','bg':'del'},inplace=True)

# %%
books.detect_tit.unique()
# Out:
# array(['en', 'da', 'pt', 'af', 'id', 'es', 'sw', 'pl', 'fi', 'sv', 'nl',
#        'et', 'fr', 'so', 'tl', 'sk', 'vi', 'it', 'ro', 'ca', 'hr', 'lt',
#        'tr', 'cy', 'no', 'de', 'cs', 'sq', 'hu', 'lv', 'sl', 'del', nan],
#       dtype=object)

# %%
books=books[books.detect_tit != 'del']

# %%
books[books.detect_tit=='da'] #Here the most of the titles are in english even if they are detected as different language.
# Out:
#              isbn  text_reviews_count  is_ebook  average_rating  \
# 2      0590417010                 193     False            4.43
# 29     0544873912                   1     False            3.22
# 117    0763624764                  31     False            3.66
# 241    1590789962                  35     False            3.11
# 344    155469891X                   9     False            3.68
# ...           ...                 ...       ...             ...
# 80342  0006481108                  10     False            3.61
# 80377  1550028286                   3     False            3.93
# 80490  039925028X                  41     False            3.67
# 80521  0606142282                  19     False            3.86
# 80571  1603209522                   3     False            4.10
#
#                                              description     format  \
# 2      In Newbery Medalist Cynthia Rylant's classic b...  Hardcover
# 29     CHIRP! CHIRP! CHIRP! It's springtime on Bradfo...  Hardcover
# 117    Fetching illustrations from an exciting new ta...  Hardcover
# 241    Goose has an important message for Bear, and h...  Hardcover
# 344    Hanna is fed up with her best friend, Lizzy, w...  Hardcover
# ...                                                  ...        ...
# 80342  Star on the rise: a pulse-racing new novel fro...  Paperback
# 80377  Short-listed for the Sheila A. Egoff Award for...  Paperback
# 80490  Caldecott Honor winner Rachel Isadora gives re...  Hardcover
# 80521  A young pig uses her ability to read to outwit...  Hardcover
# 80571  Packed with facts, stats and news from around ...  Paperback
#
#                                         publisher  num_pages         isbn13  \
# 2                                  Blue Sky Press       40.0  9780590417013
# 29                    HMH Books for Young Readers       48.0  9780544873919
# 117                                    Candlewick       40.0  9780763624767
# 241                             Boyds Mills Press       32.0  9781590789964
# 344                          Orca Book Publishers       32.0  9781554698912
# ...                                           ...        ...            ...
# 80342                        HarperCollins Canada      230.0  9780006481102
# 80377                                     Dundurn      152.0  9781550028287
# 80490  G.P. Putnam's Sons Books for Young Readers       32.0  9780399250286
# 80521                            Turtleback Books        NaN  9780606142281
# 80571                               Time For Kids      256.0  9781603209526
#
#        publication_year   book_id  ratings_count  \
# 2                  1995     89378           1331
# 29                 2017  30971686              9
# 117                2004    683151            194
# 241                2013  17469953            142
# 344                2014  18853127             35
# ...                 ...       ...            ...
# 80342              1998   2487930            100
# 80377              2008   6853284             11
# 80490              2009   6400465            151
# 80521              1998   3325443             74
# 80571              2013  15791205             41
#
#                                               title  \
# 2                                        Dog Heaven
# 29     Bradford Street Buddies: Springtime Blossoms
# 117                                        Dog Blue
# 241                                     Fox Forgets
# 344                             Best Friend Trouble
# ...                                             ...
# 80342                                      Stranded
# 80377                               Finders Keepers
# 80490                             Hansel and Gretel
# 80521                                       Hog-Eye
# 80571                    TIME For Kids Almanac 2014
#
#                                        descriptiondetect  \
# 2      in newbery medalist cynthia rylant's classic b...
# 29     chirp! chirp! chirp! it's springtime on bradfo...
# 117    fetching illustrations from an exciting new ta...
# 241    goose has an important message for bear, and h...
# 344    hanna is fed up with her best friend, lizzy, w...
# ...                                                  ...
# 80342  star on the rise: a pulse-racing new novel fro...
# 80377  short-listed for the sheila a. egoff award for...
# 80490  caldecott honor winner rachel isadora gives re...
# 80521  a young pig uses her ability to read to outwit...
# 80571  packed with facts, stats and news from around ...
#
#                                         titledetect detect_tit
# 2                                        dog heaven         da
# 29     bradford street buddies: springtime blossoms         da
# 117                                        dog blue         da
# 241                                     fox forgets         da
# 344                             best friend trouble         da
# ...                                             ...        ...
# 80342                                      stranded         da
# 80377                               finders keepers         da
# 80490                             hansel and gretel         da
# 80521                                       hog-eye         da
# 80571                    time for kids almanac 2014         da
#
# [1430 rows x 16 columns]

# %%
books.detect_tit.isnull().sum()
# Out:
# 5

# %%
books[books.detect_tit.isna()]
# Out:
#              isbn  text_reviews_count  is_ebook  average_rating  \
# 24276  0740755803                   4     False            4.19
# 33468  0753467720                  12     False            3.62
# 44626  0140371915                   1     False            3.82
# 51561  0746040997                   5     False            3.67
# 54679  068930529X                   1     False            4.25
#
#                                              description      format  \
# 24276  Every masterful image by famed photographer An...   Hardcover
# 33468  The numbers 1 to 20 have never been so creativ...   Hardcover
# 44626  Zapped into the 21st century by "The Book", th...   Paperback
# 51561  -- This delightful series of board books has b...  Board Book
# 54679  All the animals have advice for mouse on what ...   Hardcover
#
#                        publisher  num_pages         isbn13  publication_year  \
# 24276  Andrews McMeel Publishing       24.0  9780740755804              2005
# 33468                 Kingfisher       48.0  9780753467725              2012
# 44626                     Puffin       80.0  9780140371918              1997
# 51561              Usborne Books       12.0  9780746040997              2000
# 54679             Atheneum Books       24.0  9780689305290              1976
#
#         book_id  ratings_count  title  \
# 24276    699395             17    123
# 33468  13167187             37  1 2 3
# 44626   3301515             23   2095
# 51561   2621001              9  1 2 3
# 54679   3889642              4  22 23
#
#                                        descriptiondetect titledetect  \
# 24276  every masterful image by famed photographer an...         123
# 33468  the numbers 1 to 20 have never been so creativ...       1 2 3
# 44626  zapped into the 21st century by "the book", th...        2095
# 51561  -- this delightful series of board books has b...       1 2 3
# 54679  all the animals have advice for mouse on what ...       22 23
#
#       detect_tit
# 24276        NaN
# 33468        NaN
# 44626        NaN
# 51561        NaN
# 54679        NaN

# %%
books=books.drop(['detect_tit'], axis=1)

# %%
books.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'is_ebook', 'average_rating',
#        'description', 'format', 'publisher', 'num_pages', 'isbn13',
#        'publication_year', 'book_id', 'ratings_count', 'title',
#        'descriptiondetect', 'titledetect'],
#       dtype='object')

# %% [markdown]
# #### is_ebook

# %%
books.is_ebook.value_counts()
# Out:
# False    78707
# True      1938
# Name: is_ebook, dtype: int64

# %% [markdown]
# #### Format

# %%
books.format.isnull().sum()
# Out:
# 1349

# %%
books.format= books.format.fillna('not defined')

# %%
books.format.value_counts()
# Out:
# Hardcover                         40749
# Paperback                         29510
# Board Book                         3074
# ebook                              1875
# not defined                        1349
# Audio CD                           1105
# Unknown Binding                     548
# Library Binding                     422
# Audio                               422
# Mass Market Paperback               388
# Board book                          337
# Audiobook                           256
# Novelty Book                        178
# Audio Cassette                       79
# Kindle Edition                       54
# Spiral-bound                         52
# Leather Bound                        39
# paperback                            19
# Audible Audio                        14
# MP3 CD                               12
# School &amp; Library Binding          9
# Big Book                              9
# Bath Book                             8
# hardback                              8
# Turtleback                            7
# MP3 Book                              7
# Broche                                5
# Hardback                              5
# Rag Book                              5
# Softcover                             4
# Unbound                               4
# audio                                 4
# hardcover                             4
# Other Format                          4
# Boxed Set                             4
# Staple bound                          3
# picture book                          3
# Nook                                  2
# Digital Audio                         2
# Playaway                              2
# Pamphlet                              2
# Library Binding, Hardcover            2
# hard cover                            2
# cloth                                 2
# Hardcover book-plus product           2
# Hardcover + Audiobook                 1
# Foam Book                             1
# DVD                                   1
# audio cassette                        1
# Pop-Up Book                           1
# Paperback with CD-Rom                 1
# Book + Audio Cassette                 1
# Soft cover                            1
# Textbook Binding                      1
# a3                                    1
# Paperback, Hardcover                  1
# Paper                                 1
# pop up book                           1
# Playaway Audiobook                    1
# Paperback + CD                        1
# Picture Book                          1
# Picture/Flip Book                     1
# eAudiobook                            1
# Audio CD + ebook                      1
# Trade Paperback                       1
# Digital audio player                  1
# Hardcover Picture Book                1
# Binder-Bound                          1
# Perfect Paperback                     1
# Misc. Supplies                        1
# Paperback, Audio CD                   1
# Book on CD                            1
# Hardcover + CD                        1
# soft cover                            1
# Hardcover with CD                     1
# Spiral Binding in Hardcover           1
# Reinforced binding                    1
# Hardcover with Dust Jacket            1
# Cloth Bound                           1
# Padded Hardback                       1
# Box-Fold-Out                          1
# Audio CD (Unabridged)                 1
# Gebundene Ausgabe                     1
# Hardbound                             1
# Abridged Board Book                   1
# Preloaded Digital Audio Player        1
# Covercraft                            1
# Cards                                 1
# Paperback &amp; Hardcover             1
# Hardcover Pop-Up                      1
# Pop Up Book                           1
# Large Print                           1
# digital                               1
# Flexibound                            1
# MP3 Audio                             1
# audio CD                              1
# unknown                               1
# Novelty                               1
# Album                                 1
# Name: format, dtype: int64

# %% [markdown]
# #### Publisher

# %%
books.publisher.isnull().sum()
# Out:
# 924

# %%
books.publisher= books.publisher.fillna('not defined')

# %%
books.publisher.value_counts()
# Out:
# HarperCollins                           3134
# HMH Books for Young Readers             2494
# Random House Books for Young Readers    1798
# Scholastic                              1689
# Candlewick Press                        1285
#                                         ...
# Ignatius Ho                                1
# Raintree Publishers                        1
# New Chapter Press                          1
# Lothrop Lee & Shepard                      1
# Random House Value Publications,U.S.       1
# Name: publisher, Length: 6212, dtype: int64

# %% [markdown]
# ## EDA AND DATA CLEANING PART 2

# %% [markdown]
# ### Dealing with missing values after first round of data cleaning

# %%
books.shape
# Out:
# (80645, 15)

# %%
books.isnull().sum()
# Out:
# isbn                  1885
# text_reviews_count       0
# is_ebook                 0
# average_rating           0
# description              0
# format                   0
# publisher                0
# num_pages             7735
# isbn13                 461
# publication_year         0
# book_id                  0
# ratings_count            0
# title                    0
# descriptiondetect        0
# titledetect              0
# dtype: int64

# %% [markdown]
# #### ISBN and ISBN 13

# %% [markdown]
# In this case, we are going to replace the isbn and isbn13 rows presenting null values, for the value 'not defined' in both of the cases.ISBN and ISBN 13 are useful codes to identify the books, so we will keep them in case they are useful later.

# %%
books.isbn= books.isbn.fillna('not defined')

# %%
books.isbn13=books.isbn13.fillna('not defined')

# %% [markdown]
# #### Number of pages

# %%
books.num_pages.isnull().sum()
# Out:
# 7735

# %%
books.num_pages=pd.to_numeric(books.num_pages)

# %%
books.num_pages.describe().T
# Out:
# count    72910.000000
# mean        91.226978
# std        105.056666
# min          0.000000
# 25%         32.000000
# 50%         40.000000
# 75%        128.000000
# max       3816.000000
# Name: num_pages, dtype: float64

# %%
books[books.num_pages== 0]
# Out:
#              isbn  text_reviews_count  is_ebook  average_rating  \
# 86     0739356275                   7     False            3.99
# 547    1400109124                   2     False            3.81
# 586    1400090938                   4     False            3.86
# 1270   0613240820                   2     False            3.86
# 1372   0739360469                   1     False            4.19
# ...           ...                 ...       ...             ...
# 79201  0307282481                  19     False            4.16
# 79520  1400138914                   1     False            4.05
# 79776  1600246753                  25     False            3.96
# 80185  1427217254                   2     False            4.18
# 80295  1470337622                   2     False            4.20
#
#                                              description            format  \
# 86     Peter Hatcher's summer is not looking good.\nF...          Audio CD
# 547    Young Cedric Errol lives in poverty in New Yor...          Audio CD
# 586    Who is Ida B. Applewood? She is a fourth grade...    Audio Cassette
# 1270   When a man brings a pregnant border collie to ...       not defined
# 1372   One night, Mercy hears a noise. An unlikely th...             Audio
# ...                                                  ...               ...
# 79201  Mrs. Piggle-Wiggle lives in an upside-down hou...          Audio CD
# 79520  Aesop, an ancient Greek poet who was sold into...  Audio CD + ebook
# 79776  The classic Newbery Honor book that inspired t...          Audio CD
# 80185  Brave Ireneis Irene Bobbin, the dressmaker's d...         Paperback
# 80295  Love is in the air--but what does that mean fo...          Audio CD
#
#                          publisher  num_pages         isbn13  \
# 86       Listening Library (Audio)        0.0  9780739356272
# 547                   Tantor Media        0.0  9781400109128
# 586      Listening Library (Audio)        0.0  9781400090938
# 1270                   not defined        0.0  9780613240826
# 1372     Listening Library (Audio)        0.0  9780739360460
# ...                            ...        ...            ...
# 79201    Listening Library (Audio)        0.0  9780307282484
# 79520                 Tantor Media        0.0  9781400138913
# 79776  Little, Brown Young Readers        0.0  9781600246753
# 80185    Macmillan Young Listeners        0.0  9781427217257
# 80295                  not defined        0.0  9781470337629
#
#        publication_year   book_id  ratings_count  \
# 86                 2007    428336             38
# 547                2008   5844470              3
# 586                2004    988939             10
# 1270               2000   3775172              8
# 1372               2007  13134116              1
# ...                 ...       ...            ...
# 79201              2005   1290115             38
# 79520              2008   8873903              1
# 79776              2009   6080943             66
# 80185              2011  12079010              4
# 80295              2012  19877528              7
#
#                                                    title  \
# 86                                         Fudge-A-Mania
# 547                   Little Lord Fauntleroy, with eBook
# 586    Ida B: ...and Her Plans to Maximize Fun, Avoid...
# 1270                                           Abandoned
# 1372                           Mercy Watson Fights Crime
# ...                                                  ...
# 79201                                 Mrs. Piggle-Wiggle
# 79520                                     Aesop's Fables
# 79776                              Mr. Popper's Penguins
# 80185                                        Brave Irene
# 80295                                    The Third Wheel
#
#                                        descriptiondetect  \
# 86     peter hatcher's summer is not looking good.\nf...
# 547    young cedric errol lives in poverty in new yor...
# 586    who is ida b. applewood? she is a fourth grade...
# 1270   when a man brings a pregnant border collie to ...
# 1372   one night, mercy hears a noise. an unlikely th...
# ...                                                  ...
# 79201  mrs. piggle-wiggle lives in an upside-down hou...
# 79520  aesop, an ancient greek poet who was sold into...
# 79776  the classic newbery honor book that inspired t...
# 80185  brave ireneis irene bobbin, the dressmaker's d...
# 80295  love is in the air--but what does that mean fo...
#
#                                              titledetect
# 86                                         fudge-a-mania
# 547                   little lord fauntleroy, with ebook
# 586    ida b: ...and her plans to maximize fun, avoid...
# 1270                                           abandoned
# 1372                           mercy watson fights crime
# ...                                                  ...
# 79201                                 mrs. piggle-wiggle
# 79520                                     aesop's fables
# 79776                              mr. popper's penguins
# 80185                                        brave irene
# 80295                                    the third wheel
#
# [389 rows x 15 columns]

# %% [markdown]
# As number of pages is not a really important variable and there are many errors inside it, in order to keep those rows, which have really meaningful information, we will fill the null values with 0.

# %%
books.num_pages= books.num_pages.fillna(0)

# %%
books.isnull().sum()
# Out:
# isbn                  0
# text_reviews_count    0
# is_ebook              0
# average_rating        0
# description           0
# format                0
# publisher             0
# num_pages             0
# isbn13                0
# publication_year      0
# book_id               0
# ratings_count         0
# title                 0
# descriptiondetect     0
# titledetect           0
# dtype: int64

# %%
books.shape
# Out:
# (80645, 15)

# %% [markdown]
# ### DEALING WITH REPEATED TITLES AND DESCRIPTIONS

# %%
# applying the function we created at the beginning of the notebook
get_uniques(books)
# Out:
# isbn : 78761 unique values.
# text_reviews_count : 980 unique values.
# is_ebook : {False, True}
# average_rating : 286 unique values.
# description : 73913 unique values.
# format : 99 unique values.
# publisher : 6212 unique values.
# num_pages : 643 unique values.
# isbn13 : 80185 unique values.
# publication_year : 115 unique values.
# book_id : 80645 unique values.
# ratings_count : 3920 unique values.
# title : 64901 unique values.
# descriptiondetect : 73894 unique values.
# titledetect : 64123 unique values.

# %% [markdown]
# We can notice that the titledetect and descriptiondetect have less unique values than the title and the description.
# So we are going to use those columns in the datacleaning, because they are already in lowercases.

# %%
books.titledetect.nunique()
# Out:
# 64123

# %%
books.descriptiondetect.nunique()
# Out:
# 73894

# %%
books.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'is_ebook', 'average_rating',
#        'description', 'format', 'publisher', 'num_pages', 'isbn13',
#        'publication_year', 'book_id', 'ratings_count', 'title',
#        'descriptiondetect', 'titledetect'],
#       dtype='object')

# %%
books.descriptiondetect.value_counts()
# Out:
# boyds mills press publishes a wide range of high-quality fiction and nonfiction picture books, chapter books, novels, and nonfiction                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      45
# source of legend and lyric, reference and conjecture, alice's adventures in wonderland is for most children pure pleasure in prose. while adults try to decipher lewis carroll's putative use of complex mathematical codes in the text, or debate his alleged use of opium, young readers simply dive with alice through the rabbit hole, pursuing "the dream-child moving through a land / of wonders wild and new." there they encounter the white rabbit, the queen of hearts, the mock turtle, and the mad hatter, among a multitude of other characters--extinct, fantastical, and commonplace creatures. alice journeys through this wonderland, trying to fathom the meaning of her strange experiences. but they turn out to be "curiouser and curiouser," seemingly without moral or sense.\nfor more than 130 years, children have reveled in the delightfully non-moralistic, non-educational virtues of this classic. in fact, at every turn, alice's new companions scoff at her traditional education. the mock turtle, for example, remarks that he took the "regular course" in school: reeling, writhing, and branches of arithmetic-ambition, distraction, uglification, and derision. carroll believed john tenniel's illustrations were as important as his text. naturally, carroll's instincts were good; the masterful drawings are inextricably tied to the well-loved story.    34
# follow the yellow brick road!\ndorothy thinks she's lost forever when a tornado whirls her and her dog, toto, into a magical world. to get home, she must find the wonderful wizard in the emerald city of oz. on the way she meets the scarecrow, the tin woodman and the cowardly lion. but the wicked witch of the west has her own plans for the new arrival - will dorothy ever see kansas again?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    32
# by falling down a rabbit hole and stepping through a mirror, alice experiences unusual adventures with a variety of nonsensical characters.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               30
# when orphaned mary lennox comes to live at her uncle's great house on the yorkshire moors, she finds it full of secrets. the mansion has nearly one hundred rooms, and her uncle keeps himself locked up. and at night, she hears the sound of crying down one of the long corridors.\nthe gardens surrounding the large property are mary's only escape. then, mary discovers a secret garden, surrounded by walls and locked with a missing key. one day, with the help of two unexpected companions, she discovers a way in. is everything in the garden dead, or can mary bring it back to life?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      30
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ..
# one hundred ninety beloved stories from the old and new testament are told in simple text and with vivid, full-color art on every page. related questions after each story offer kids a time of reflection. this book has been a favorite of children around the world for more than 30 years.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# featuring performances by: william bennett, elayne bennett, stephen collins, vondie curtis-hall, megan gallagher, charlton heston, simon jones, rita moreno, tonya pinkins, richard thomas, and betty white.\nmore than two million readers and listeners have used william bennett's "the book of virtues" to help their families learn the essential traits of good character. now his inspiring and instructive volume, "the moral compass, " offers more examples of good and bad, right and wrong, in great works from literature and in exemplary stories from history.\norganized by the stages along life's journey, "the moral compass" moves from the first character lessons taught in the home to the countless choices that call the virtues into play. the stories and poems continually serve as reference points on a moral compass, guiding the reader through the ethical and spiritual challenges along the pathway of life: leaving home, entering into marriage, easing the burdens of others, nurturing one's children, and fulfilling the obligations of citizenship and leadership.\noffering well-known examples from western history and mythology along with tales and folklore from asia, africa, and latin america, "the moral compass" is an indispensable guide for the family to meet the challenges of life at any age.                                                   1
# woody, buzz lightyear, their pals, and a whole crew of new toys are along for the ride in this nonstop adventure. readers can turn the pages at the sound of the chime and follow along with the word-for-word narration on the cd. with original character voices and movie sound effects from the smash-hit toy story 3, this thrilling read-along brings all the action to life!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# fashion! models! deadlines! \nidentical twins elizabeth and jessica wakefield are interning at flair--the hippest fashion magazine ever! as the assistant to famous photographer quentin berg, jessica thought she'd be working on glamorous photo shoots. instead, she has to clean up after simone, a supermodel with a bad attitude. but not for long. jessica comes up with a scheme to ditch simone and get the modeling job for herself. all she has to do is make quentin fall in love with her!\nelizabeth is thrilled to work in the managing editor's busy office. but she's not so thrilled when her longtime boyfriend, todd wilkens, comes to visit her and gets discovered as a model! todd's ego quickly spins out of control, and elizabeth is devastated when she catches him flirting with simone. will todd fall into the clutches of the evil supermodel?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# rhyming text depicts the pleasures of the outdoors in all kinds of weather, through the four seasons.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# Name: descriptiondetect, Length: 73894, dtype: int64

# %%
books[books.descriptiondetect.map(books.descriptiondetect.value_counts())== 32]
# Out:
#               isbn  text_reviews_count  is_ebook  average_rating  \
# 2537    0261660578                   3     False            3.98
# 3183    1843546590                   1     False            3.98
# 3184    1905716524                   7     False            3.98
# 5849    0907785751                   2     False            3.98
# 8906   not defined                   3     False            3.98
# 10679   1843913909                  13     False            3.98
# 14382   0395618045                   4     False            3.98
# 22104   0141305460                   5     False            3.98
# 22340   0517500868                   5     False            3.98
# 22573   1435139739                  44     False            3.98
# 25537   1898000069                   1     False            3.98
# 27336   1403764964                   1     False            3.98
# 29634   8420604623                   1     False            3.98
# 31091   1559027827                   4     False            3.98
# 33386   0140623795                  19     False            3.98
# 37988   0679887563                   1     False            3.98
# 40374   1858137306                   8     False            3.98
# 41784   043923641X                   7     False            3.98
# 43149   004805826X                   1     False            3.98
# 49228   0486291162                  28     False            3.98
# 50007   0816725659                   3     False            3.98
# 52223  not defined                   9     False            3.98
# 60306   0528826948                  10     False            3.98
# 61988   044803266X                   2     False            3.98
# 64313   8497893220                  10     False            3.98
# 67803   0141195010                   3     False            3.98
# 74184   0141321024                 123     False            3.98
# 74499   0448060264                   7     False            3.98
# 74500   0893759910                   8     False            3.98
# 76475   1908533307                   9     False            3.98
# 77113   0307941639                   1     False            3.98
# 80421   0140621679                5883     False            3.98
#
#                                              description       format  \
# 2537   Follow the yellow brick road!\nDorothy thinks ...  not defined
# 3183   Follow the yellow brick road!\nDorothy thinks ...    Hardcover
# 3184   Follow the yellow brick road!\nDorothy thinks ...    Hardcover
# 5849   Follow the yellow brick road!\nDorothy thinks ...  not defined
# 8906   Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 10679  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 14382  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 22104  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 22340  Follow the yellow brick road!\nDorothy thinks ...    Hardcover
# 22573  Follow the yellow brick road!\nDorothy thinks ...    Hardcover
# 25537  Follow the yellow brick road!\nDorothy thinks ...    Hardcover
# 27336  Follow the yellow brick road!\nDorothy thinks ...  not defined
# 29634  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 31091  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 33386  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 37988  Follow the yellow brick road!\nDorothy thinks ...    Hardcover
# 40374  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 41784  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 43149  Follow the yellow brick road!\nDorothy thinks ...    Hardcover
# 49228  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 50007  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 52223  Follow the yellow brick road!\nDorothy thinks ...    Hardcover
# 60306  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 61988  Follow the yellow brick road!\nDorothy thinks ...  not defined
# 64313  Follow the yellow brick road!\nDorothy thinks ...    Hardcover
# 67803  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 74184  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 74499  Follow the yellow brick road!\nDorothy thinks ...    Hardcover
# 74500  Follow the yellow brick road!\nDorothy thinks ...  not defined
# 76475  Follow the yellow brick road!\nDorothy thinks ...    Paperback
# 77113  Follow the yellow brick road!\nDorothy thinks ...     Audio CD
# 80421  Follow the yellow brick road!\nDorothy thinks ...    Paperback
#
#                                   publisher  num_pages         isbn13  \
# 2537                          Diamond Books      159.0  9780261660571
# 3183                               Atlantic      304.0  9781843546597
# 3184                    Collector's Library      184.0  9781905716524
# 5849                       Robert Frederick        0.0  9780907785750
# 8906                        Dalmatian Press      180.0  9781453064603
# 10679                        Hesperus Press      144.0  9781843913900
# 14382                           not defined        0.0  9780395618042
# 22104                                Puffin      189.0  9780141305462
# 22340            Clarkson Potter Publishers      384.0  9780517500866
# 22573                        Barnes & Noble      224.0  9781435139732
# 25537                        Barefoot Books      270.0  9781898000068
# 27336                           not defined      180.0    not defined
# 29634                  Alianza Editorial Sa        0.0  9788420604626
# 31091                      Aerie Books Ltc.      168.0  9781559027823
# 33386                      Penguin Classics      154.0  9780140623796
# 37988  Random House Books for Young Readers       96.0  9780679887560
# 40374            Parragon Book Service Ltd.      151.0  9781858137308
# 41784                 Scholastic Paperbacks      160.0  9780439236416
# 43149                 Grosset & Dunlap, inc      205.0    not defined
# 49228                    Dover Publications      140.0  9780486291161
# 50007                  Troll Communications      166.0  9780816725656
# 52223                  Barnes & Noble, Inc.      224.0  9781435147614
# 60306                          Rand McNally       61.0    not defined
# 61988                      Grosset & Dunlap      265.0  9780448032665
# 64313         The Children's Golden Library      159.0    not defined
# 67803           Penguin Books, Limited (UK)      208.0  9780141195018
# 74184                          Puffin Books      190.0  9780141321028
# 74499                      Grosset & Dunlap      207.0  9780448060262
# 74500                       Watermill Press      166.0    not defined
# 76475    Atlantic Publishing, Croxley Green      143.0  9781908533302
# 77113                     Listening Library        4.0  9780307941633
# 80421                               Penguin      154.0  9780140621679
#
#        publication_year   book_id  ratings_count  \
# 2537               1993   7569458             14
# 3183               2008   7739742              7
# 3184               2010   7739741             60
# 5849               2001   2889190             27
# 8906               2013  18631990             19
# 10679              2013  17729145             92
# 14382              1992   2603731             13
# 22104              1999   3309639             45
# 22340              1973    719973             13
# 22573              2012  15945612            256
# 25537              1994   2157734              7
# 27336              2011  12409128              8
# 29634              1999   2603744              2
# 31091              1998    430487             17
# 33386              2007   6277065            150
# 37988              1997   1382789             12
# 40374              1994  15789266            123
# 41784              2001    236074            109
# 43149              1976  18404937              3
# 49228              1996    170610            331
# 50007              2002   3416658             15
# 52223              2013  19450693             45
# 60306              1977   1014204             91
# 61988              1976    762676              7
# 64313              2004  15773076             88
# 67803              2012  15924964             51
# 74184              2008   2038033           1741
# 74499              1992    483757             46
# 74500              1983    483756             28
# 76475              2012  14575293             62
# 77113              2012  16309732              7
# 80421              1995    236093         251691
#
#                                                    title  \
# 2537                                    The Wizard of Oz
# 3183                     The Wizard of Oz. L. Frank Baum
# 3184                                    The Wizard of Oz
# 5849                                    The Wizard of Oz
# 8906                           The Wonderful of World Oz
# 10679                The Wonderful Wizard of Oz (Oz, #1)
# 14382                         The Wonderful Wizard of Oz
# 22104                                   The Wizard of Oz
# 22340  The Annotated Wizard of Oz: The Wonderful Wiza...
# 22573                         The Wonderful Wizard of Oz
# 25537               Wizard of Oz (Little Barefoot Books)
# 27336                The Wonderful Wizard of Oz (Oz, #1)
# 29634  El Maravilloso Mago De Oz/the Wonderful Wizard...
# 31091                                   The Wizard Of Oz
# 33386                The Wonderful Wizard of Oz (Oz, #1)
# 37988                                   The Wizard of Oz
# 40374                                   The Wizard of Oz
# 41784                                   The Wizard Of Oz
# 43149                                   The Wizard of Oz
# 49228                The Wonderful Wizard of Oz (Oz, #1)
# 50007                         The Wonderful Wizard of Oz
# 52223                                   The Wizard of Oz
# 60306                                   The Wizard of Oz
# 61988       The Wonderful Wizard of Oz (Books of Oz, #1)
# 64313                                   The Wizard of Oz
# 67803                         The Wonderful Wizard of Oz
# 74184                          The Wizard of Oz (Oz, #1)
# 74499                                       Wizard Of Oz
# 74500                         The Wonderful Wizard of Oz
# 76475                         The Wonderful Wizard of Oz
# 77113                         The Wonderful Wizard of Oz
# 80421                The Wonderful Wizard of Oz (Oz, #1)
#
#                                        descriptiondetect  \
# 2537   follow the yellow brick road!\ndorothy thinks ...
# 3183   follow the yellow brick road!\ndorothy thinks ...
# 3184   follow the yellow brick road!\ndorothy thinks ...
# 5849   follow the yellow brick road!\ndorothy thinks ...
# 8906   follow the yellow brick road!\ndorothy thinks ...
# 10679  follow the yellow brick road!\ndorothy thinks ...
# 14382  follow the yellow brick road!\ndorothy thinks ...
# 22104  follow the yellow brick road!\ndorothy thinks ...
# 22340  follow the yellow brick road!\ndorothy thinks ...
# 22573  follow the yellow brick road!\ndorothy thinks ...
# 25537  follow the yellow brick road!\ndorothy thinks ...
# 27336  follow the yellow brick road!\ndorothy thinks ...
# 29634  follow the yellow brick road!\ndorothy thinks ...
# 31091  follow the yellow brick road!\ndorothy thinks ...
# 33386  follow the yellow brick road!\ndorothy thinks ...
# 37988  follow the yellow brick road!\ndorothy thinks ...
# 40374  follow the yellow brick road!\ndorothy thinks ...
# 41784  follow the yellow brick road!\ndorothy thinks ...
# 43149  follow the yellow brick road!\ndorothy thinks ...
# 49228  follow the yellow brick road!\ndorothy thinks ...
# 50007  follow the yellow brick road!\ndorothy thinks ...
# 52223  follow the yellow brick road!\ndorothy thinks ...
# 60306  follow the yellow brick road!\ndorothy thinks ...
# 61988  follow the yellow brick road!\ndorothy thinks ...
# 64313  follow the yellow brick road!\ndorothy thinks ...
# 67803  follow the yellow brick road!\ndorothy thinks ...
# 74184  follow the yellow brick road!\ndorothy thinks ...
# 74499  follow the yellow brick road!\ndorothy thinks ...
# 74500  follow the yellow brick road!\ndorothy thinks ...
# 76475  follow the yellow brick road!\ndorothy thinks ...
# 77113  follow the yellow brick road!\ndorothy thinks ...
# 80421  follow the yellow brick road!\ndorothy thinks ...
#
#                                              titledetect
# 2537                                    the wizard of oz
# 3183                     the wizard of oz. l. frank baum
# 3184                                    the wizard of oz
# 5849                                    the wizard of oz
# 8906                           the wonderful of world oz
# 10679                the wonderful wizard of oz (oz, #1)
# 14382                         the wonderful wizard of oz
# 22104                                   the wizard of oz
# 22340  the annotated wizard of oz: the wonderful wiza...
# 22573                         the wonderful wizard of oz
# 25537               wizard of oz (little barefoot books)
# 27336                the wonderful wizard of oz (oz, #1)
# 29634  el maravilloso mago de oz/the wonderful wizard...
# 31091                                   the wizard of oz
# 33386                the wonderful wizard of oz (oz, #1)
# 37988                                   the wizard of oz
# 40374                                   the wizard of oz
# 41784                                   the wizard of oz
# 43149                                   the wizard of oz
# 49228                the wonderful wizard of oz (oz, #1)
# 50007                         the wonderful wizard of oz
# 52223                                   the wizard of oz
# 60306                                   the wizard of oz
# 61988       the wonderful wizard of oz (books of oz, #1)
# 64313                                   the wizard of oz
# 67803                         the wonderful wizard of oz
# 74184                          the wizard of oz (oz, #1)
# 74499                                       wizard of oz
# 74500                         the wonderful wizard of oz
# 76475                         the wonderful wizard of oz
# 77113                         the wonderful wizard of oz
# 80421                the wonderful wizard of oz (oz, #1)

# %%
books[(books.descriptiondetect.map(books.descriptiondetect.value_counts()) >= 2) & (books.titledetect.map(books.titledetect.value_counts())>= 2)].sort_values('titledetect', ascending=False)
# Out:
#              isbn  text_reviews_count  is_ebook  average_rating  \
# 65347  0802727913                   2     False            3.35
# 64625  0802727905                  38     False            3.35
# 13998  1442412720                  50     False            4.11
# 10575  074596270X                   2     False            3.47
# 14757  0745963234                  20     False            3.47
# ...           ...                 ...       ...             ...
# 72619  1442499281                   5     False            4.06
# 3002   0399230130                  99     False            3.90
# 12177  039961172X                  14     False            3.90
# 71531  0547531176                   3      True            4.36
# 63285  0618616829                   2     False            4.36
#
#                                              description      format  \
# 65347  When night has come and the moon shines bright...   Hardcover
# 64625  When night has come and the moon shines bright...   Hardcover
# 13998                           A Simon & Schuster eBook   Hardcover
# 10575  A strikingly illustrated story with a heartwar...   Paperback
# 14757  A strikingly illustrated story with a heartwar...   Hardcover
# ...                                                  ...         ...
# 72619                           A Simon & Schuster eBook  Board Book
# 3002   Joyously colored animals, riding on a train to...  Board book
# 12177  Joyously colored animals, riding on a train to...   Hardcover
# 71531  Once upon a time, children imagined St. Nichol...       ebook
# 63285  Once upon a time, children imagined St. Nichol...   Hardcover
#
#                          publisher  num_pages         isbn13  \
# 65347             Walker Childrens       32.0  9780802727916
# 64625             Walker Childrens       32.0  9780802727909
# 13998             Beach Lane Books       40.0  9781442412729
# 10575                  Lion Hudson       32.0  9780745962702
# 14757                  Lion Hudson       32.0  9780745963235
# ...                            ...        ...            ...
# 72619                 Little Simon       36.0  9781442499287
# 3002                Philomel Books       20.0  9780399230134
# 12177               Philomel Books       34.0  9780399611728
# 71531             Houghton Mifflin        0.0  9780547531175
# 63285  HMH Books for Young Readers       32.0  9780618616824
#
#        publication_year   book_id  ratings_count  \
# 65347              2012  13167169              7
# 64625              2012  13167167            185
# 13998              2010   7866583            223
# 10575              2013  13162256              8
# 14757              2012  13198862            120
# ...                 ...       ...            ...
# 72619              2014  18668444             31
# 3002               1996    532249           1203
# 12177              1982   3004699             66
# 71531              2005   8846499             15
# 63285              2005    633698              9
#
#                                              title  \
# 65347                          Zoom, Rocket, Zoom!
# 64625                          Zoom, Rocket, Zoom!
# 13998  ZooBorns!: Zoo Babies from Around the World
# 10575                                     Zoo Girl
# 14757                                     Zoo Girl
# ...                                            ...
# 72619                                   1-2-3 Peas
# 3002                            1, 2, 3 to the Zoo
# 12177                           1, 2, 3 to the Zoo
# 71531             'Twas the Night Before Christmas
# 63285             'Twas the Night Before Christmas
#
#                                        descriptiondetect  \
# 65347  when night has come and the moon shines bright...
# 64625  when night has come and the moon shines bright...
# 13998                           a simon & schuster ebook
# 10575  a strikingly illustrated story with a heartwar...
# 14757  a strikingly illustrated story with a heartwar...
# ...                                                  ...
# 72619                           a simon & schuster ebook
# 3002   joyously colored animals, riding on a train to...
# 12177  joyously colored animals, riding on a train to...
# 71531  once upon a time, children imagined st. nichol...
# 63285  once upon a time, children imagined st. nichol...
#
#                                        titledetect
# 65347                          zoom, rocket, zoom!
# 64625                          zoom, rocket, zoom!
# 13998  zooborns!: zoo babies from around the world
# 10575                                     zoo girl
# 14757                                     zoo girl
# ...                                            ...
# 72619                                   1-2-3 peas
# 3002                            1, 2, 3 to the zoo
# 12177                           1, 2, 3 to the zoo
# 71531             'twas the night before christmas
# 63285             'twas the night before christmas
#
# [8785 rows x 15 columns]

# %%
books1=books.sort_values('text_reviews_count', ascending= False)

# %%
books1
# Out:
#              isbn  text_reviews_count  is_ebook  average_rating  \
# 71712  0385732554               49850     False            4.12
# 20152  0375869026               31536     False            4.43
# 34990  043965548X               28561     False            4.53
# 13148  0156012197               16639     False            4.28
# 70661  0439244196               14851     False            3.93
# ...           ...                 ...       ...             ...
# 28737  0613504968                   0     False            3.98
# 37196  1556614071                   0     False            3.43
# 62302  3150091608                   0     False            4.00
# 21328  0824918452                   0     False            3.77
# 7115   146624514X                   0     False            3.75
#
#                                              description  \
# 71712  Twelve-year-old Jonas lives in a seemingly ide...
# 20152  I won't describe what I look like. Whatever yo...
# 34990  Harry Potter's third year at Hogwarts is full ...
# 13148  Moral allegory and spiritual autobiography, Th...
# 70661  Stanley tries to dig up the truth in this inve...
# ...                                                  ...
# 28737  To explain the markings on their faces and tai...
# 37196  An exciting series of chapter books for reader...
# 62302  Source of legend and lyric, reference and conj...
# 21328  A classic bestseller presented in a new size w...
# 7115   Saving Mom!\nWhen James and his parents move f...
#
#                       format                                    publisher  \
# 71712              Paperback                                        Ember
# 20152              Hardcover                                        Knopf
# 34990  Mass Market Paperback                              Scholastic Inc.
# 13148              Paperback                               Harcourt, Inc.
# 70661              Paperback                                   Scholastic
# ...                      ...                                          ...
# 28737              Hardcover                             Turtleback Books
# 37196              Paperback                     Bethany House Publishers
# 62302              Paperback                          Reclam Philipp Jun.
# 21328             Board Book                            WorthyKids/ideals
# 7115               Paperback  Createspace Independent Publishing Platform
#
#        num_pages         isbn13  publication_year   book_id  ratings_count  \
# 71712      208.0  9780385732550              2006      3636        1311422
# 20152      316.0  9780375869020              2012  11387515         255461
# 34990      435.0  9780439655484              2004         5        1876252
# 13148       93.0  9780156012195              2000    157993         763309
# 70661      233.0  9780439244190              2000     38709         766680
# ...          ...            ...               ...       ...            ...
# 28737       40.0  9780613504966              2001   9277714              7
# 37196       59.0  9781556614071              1994    341579             46
# 62302      148.0  9783150091609              1984    853469             38
# 21328       22.0  9780824918453              2010   9791536             28
# 7115        50.0  9781466245143              2013  17893785              5
#
#                                                    title  \
# 71712                          The Giver (The Giver, #1)
# 20152                                 Wonder (Wonder #1)
# 34990  Harry Potter and the Prisoner of Azkaban (Harr...
# 13148                                  The Little Prince
# 70661                                  Holes (Holes, #1)
# ...                                                  ...
# 28737                     Sagwa, the Chinese Siamese Cat
# 37196                       The Mystery of the Wrong Dog
# 62302                   Alice's Adventures in Wonderland
# 21328                             The Story of Christmas
# 7115                                  James and the Mini
#
#                                        descriptiondetect  \
# 71712  twelve-year-old jonas lives in a seemingly ide...
# 20152  i won't describe what i look like. whatever yo...
# 34990  harry potter's third year at hogwarts is full ...
# 13148  moral allegory and spiritual autobiography, th...
# 70661  stanley tries to dig up the truth in this inve...
# ...                                                  ...
# 28737  to explain the markings on their faces and tai...
# 37196  an exciting series of chapter books for reader...
# 62302  source of legend and lyric, reference and conj...
# 21328  a classic bestseller presented in a new size w...
# 7115   saving mom!\nwhen james and his parents move f...
#
#                                              titledetect
# 71712                          the giver (the giver, #1)
# 20152                                 wonder (wonder #1)
# 34990  harry potter and the prisoner of azkaban (harr...
# 13148                                  the little prince
# 70661                                  holes (holes, #1)
# ...                                                  ...
# 28737                     sagwa, the chinese siamese cat
# 37196                       the mystery of the wrong dog
# 62302                   alice's adventures in wonderland
# 21328                             the story of christmas
# 7115                                  james and the mini
#
# [80645 rows x 15 columns]

# %%
books1.shape
# Out:
# (80645, 15)

# %%
books2=books1.drop_duplicates(subset=['descriptiondetect','titledetect'], keep= 'first')

# %%
books2.shape
# Out:
# (76213, 15)

# %%
books2[(books2.titledetect.map(books2.titledetect.value_counts()) >= 2)].sort_values('titledetect', ascending=False)
# Out:
#              isbn  text_reviews_count  is_ebook  average_rating  \
# 2736   055315608X                   1     False            3.68
# 66272  0440414024                   7     False            3.68
# 32192  1101002697                   1      True            4.05
# 29781  1595142959                  43     False            4.05
# 19641  037586847X                  18     False            3.75
# ...           ...                 ...       ...             ...
# 67217  0688156347                   8     False            3.81
# 22419  0688091741                   5     False            3.81
# 15002  0688091733                   7     False            3.81
# 77729  0763614521                 103     False            4.11
# 24995  0763621935                   6     False            4.11
#
#                                              description      format  \
# 2736   A painfully shy young boy befriends a homeless...   Paperback
# 66272  Zucchini knows there's more to life than his c...   Paperback
# 32192  Are You a Believer in Fanciful Things? In Pira...       ebook
# 29781  Are You a Believer in Fanciful Things? In Pira...   Paperback
# 19641  Winter weather is keeping children from visiti...   Hardcover
# ...                                                  ...         ...
# 67217  Here are\nLittle Guy,\nLittle Pumpkin,\nand\nL...  Board Book
# 22419  Here are Little Guy, Little Pumpkin, and Littl...   Hardcover
# 15002  Here are Little Guy, Little Pumpkin,and Little...   Hardcover
# 77729  The Barnes & Noble Review\nA little girl's dre...   Hardcover
# 24995  "This is first-rate child's fare. . . . Sure t...   Paperback
#
#                            publisher  num_pages         isbn13  \
# 2736                         Skylark      160.0  9780553156089
# 66272                       Yearling      160.0  9780440414025
# 32192                      Razorbill        0.0  9781101002698
# 29781                      Razorbill      288.0  9781595142955
# 19641  Knopf Books for Young Readers       40.0  9780375868474
# ...                              ...        ...            ...
# 67217              Greenwillow Books        0.0  9780688156343
# 22419              Greenwillow Books       32.0  9780688091743
# 15002              Greenwillow Books       40.0  9780688091736
# 77729                     Candlewick       32.0  9780763614522
# 24995               Candlewick Press       32.0  9780763621933
#
#        publication_year   book_id  ratings_count  \
# 2736               1984    652287              8
# 66272              1984   2865870             59
# 32192              2008   8910936              2
# 29781              2010   7911670            110
# 19641              2011  11331530             73
# ...                 ...       ...            ...
# 67217              1997   1296580             97
# 22419              1990   3875332             11
# 15002              1990   2599431             60
# 77729              2001   1068302            411
# 24995              2003   1668176             38
#
#                                  title  \
# 2736                          Zucchini
# 66272                         Zucchini
# 32192                       Zorgamazoo
# 29781                       Zorgamazoo
# 19641                         ZooZical
# ...                                ...
# 67217  "More More More," Said the Baby
# 22419  "More More More," Said the Baby
# 15002  "More More More," Said the Baby
# 77729     "Let's Get a Pup!" Said Kate
# 24995     "Let's Get a Pup!" Said Kate
#
#                                        descriptiondetect  \
# 2736   a painfully shy young boy befriends a homeless...
# 66272  zucchini knows there's more to life than his c...
# 32192  are you a believer in fanciful things? in pira...
# 29781  are you a believer in fanciful things? in pira...
# 19641  winter weather is keeping children from visiti...
# ...                                                  ...
# 67217  here are\nlittle guy,\nlittle pumpkin,\nand\nl...
# 22419  here are little guy, little pumpkin, and littl...
# 15002  here are little guy, little pumpkin,and little...
# 77729  the barnes & noble review\na little girl's dre...
# 24995  "this is first-rate child's fare. . . . sure t...
#
#                            titledetect
# 2736                          zucchini
# 66272                         zucchini
# 32192                       zorgamazoo
# 29781                       zorgamazoo
# 19641                         zoozical
# ...                                ...
# 67217  "more more more," said the baby
# 22419  "more more more," said the baby
# 15002  "more more more," said the baby
# 77729     "let's get a pup!" said kate
# 24995     "let's get a pup!" said kate
#
# [19453 rows x 15 columns]

# %%
books3=books2.drop_duplicates(subset=['titledetect'], keep= 'first')

# %%
books3.shape
# Out:
# (64123, 15)

# %%
books3.titledetect.value_counts()
# Out:
# dinosaurs: a visual encyclopedia                             1
# stella batts needs a new name (stella batts, #1)             1
# something beginning with blue. nick sharratt, sally symes    1
# brigid's cloak: an ancient irish story                       1
# kindergarten cat                                             1
#                                                             ..
# princess grace and the little lost kitten                    1
# frazzle                                                      1
# the blizzard on blue mountain (cabin creek mysteries #5)     1
# rhymes & reasons                                             1
# there was a tree                                             1
# Name: titledetect, Length: 64123, dtype: int64

# %%
books3[books3.descriptiondetect.map(books3.descriptiondetect.value_counts())>= 2].sort_values('descriptiondetect', ascending=False)
# Out:
#              isbn  text_reviews_count  is_ebook  average_rating  \
# 68837  0152063897                 123     False            4.21
# 52228  0547850603                   1     False            4.21
# 10216  1848778570                   1     False            3.60
# 18469  0763666580                  22     False            3.60
# 30817  0694016608                  68     False            3.43
# ...           ...                 ...       ...             ...
# 25840  9584504452                   1     False            3.84
# 19156  0749732105                 115     False            4.32
# 73860  1405230576                  15     False            4.32
# 73351  0340042443                   1     False            3.80
# 41590  1444913484                   1     False            3.80
#
#                                              description     format  \
# 68837  Zooom! Wooeeee . . . ! "Make way!"The big city...  Hardcover
# 52228  Zooom! Wooeeee . . . ! "Make way!"The big city...   Big Book
# 10216  Zookeeper Mr. Peek causes pandemonium again!\n...  Paperback
# 18469  Zookeeper Mr. Peek causes pandemonium again!\n...  Hardcover
# 30817  Your world. My world. I can swing right over t...  Paperback
# ...                                                  ...        ...
# 25840  "Beware a mermaid's wrath!"\nThe mermaid Soop ...  Hardcover
# 19156  "A land at the top of a tree!" said Connie. "I...  Paperback
# 73860  "A land at the top of a tree!" said Connie. "I...  Paperback
# 73351  "A car is stolen-- and Peter and Janet witness...  Paperback
# 41590  "A car is stolen-- and Peter and Janet witness...  Paperback
#
#                          publisher  num_pages         isbn13  \
# 68837  HMH Books for Young Readers       40.0  9780152063894
# 52228  HMH Books for Young Readers       40.0  9780547722146
# 10216                Templar Books       40.0  9781848778573
# 18469                      Templar       40.0  9780763666583
# 30817                HarperCollins       32.0  9780694016600
# ...                            ...        ...            ...
# 25840                  not defined        0.0  9789584504456
# 19156                       Egmont      185.0  9780749732103
# 73860                       Egmont      192.0  9781405230575
# 73351                 Knight Books      128.0  9780340042441
# 41590                  not defined        0.0  9781444913484
#
#        publication_year   book_id  ratings_count  \
# 68837              2009   6399395           2022
# 52228              2012  13356695              1
# 10216              2013  17594073              6
# 18469              2014  18209409             75
# 30817              2004    237337            554
# ...                 ...       ...            ...
# 25840              2007   2983697             13
# 19156              1997    473623          11899
# 73860              2007    319977            171
# 73351              1970   2657284             10
# 41590              2013  21227332              3
#
#                                                    title  \
# 68837                    Little Blue Truck Leads the Way
# 52228           Little Blue Truck Leads the Way big book
# 10216             Pandamonium at Peek Zoo. Kevin Waldron
# 18469                           Panda-monium at Peek Zoo
# 30817            My World: A Companion to Goodnight Moon
# ...                                                  ...
# 25840  El Refugio De Las Hadas Y La Busqueda De La Va...
# 19156  The Folk of the Faraway Tree (The Faraway Tree...
# 73860                       The Folk of the Faraway Tree
# 73351                            Good Work, Secret Seven
# 41590           Secret Seven: 6: Good Work, Secret Seven
#
#                                        descriptiondetect  \
# 68837  zooom! wooeeee . . . ! "make way!"the big city...
# 52228  zooom! wooeeee . . . ! "make way!"the big city...
# 10216  zookeeper mr. peek causes pandemonium again!\n...
# 18469  zookeeper mr. peek causes pandemonium again!\n...
# 30817  your world. my world. i can swing right over t...
# ...                                                  ...
# 25840  "beware a mermaid's wrath!"\nthe mermaid soop ...
# 19156  "a land at the top of a tree!" said connie. "i...
# 73860  "a land at the top of a tree!" said connie. "i...
# 73351  "a car is stolen-- and peter and janet witness...
# 41590  "a car is stolen-- and peter and janet witness...
#
#                                              titledetect
# 68837                    little blue truck leads the way
# 52228           little blue truck leads the way big book
# 10216             pandamonium at peek zoo. kevin waldron
# 18469                           panda-monium at peek zoo
# 30817            my world: a companion to goodnight moon
# ...                                                  ...
# 25840  el refugio de las hadas y la busqueda de la va...
# 19156  the folk of the faraway tree (the faraway tree...
# 73860                       the folk of the faraway tree
# 73351                            good work, secret seven
# 41590           secret seven: 6: good work, secret seven
#
# [3052 rows x 15 columns]

# %%
books4=books3.drop_duplicates(subset=['descriptiondetect'], keep= 'first') 
#in the end we decide to drop duplicates descriptions as well

# %%
books4.shape
# Out:
# (62395, 15)

# %%
books4.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'is_ebook', 'average_rating',
#        'description', 'format', 'publisher', 'num_pages', 'isbn13',
#        'publication_year', 'book_id', 'ratings_count', 'title',
#        'descriptiondetect', 'titledetect'],
#       dtype='object')

# %%
file_name='descriptionsdfclean.csv'
books4.to_csv(file_name, index=False)
