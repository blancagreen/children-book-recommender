# %% [markdown]
# ## Importing the libraries and data

# %%
import pandas as pd
import numpy as np
import os
pd.options.display.max_rows=350
pd.options.display.max_columns=40


import warnings
warnings.filterwarnings('ignore')

# %%
#df=pd.read_csv('CHILDREN_TOTAL_FOR_RECOMMENDER.csv')
df=pd.read_csv('FINAL_COMPLETE_DF.csv')

# %%
df.columns
# Out:
# Index(['user_id', 'book_id', 'review_id', 'rating', 'review_text', 'isbn',
#        'text_reviews_count', 'is_ebook', 'average_rating', 'description',
#        'format', 'publisher', 'num_pages', 'isbn13', 'publication_year',
#        'ratings_count', 'title', 'descriptiondetect', 'titledetect',
#        'review_text_detect'],
#       dtype='object')

# %% [markdown]
# ## Transforming the data and creating the sparse matrix

# %%
from scipy.sparse import csr_matrix

def create_X(df):
    """
    Generates a sparse matrix from ratings dataframe.
    
    Args:
        df: pandas dataframe
    
    Returns:
        X: sparse matrix
        user_mapper: dict that maps user id's to user indices
        user_inv_mapper: dict that maps user indices to user id's
        book_mapper: dict that maps book id's to book indices
        book_inv_mapper: dict that maps book indices to book id's
    """
    N = df['user_id'].nunique()
    M = df['book_id'].nunique()

    user_mapper = dict(zip(np.unique(df["user_id"]), list(range(N))))
    book_mapper = dict(zip(np.unique(df["book_id"]), list(range(M))))
    
    user_inv_mapper = dict(zip(list(range(N)), np.unique(df["user_id"])))
    book_inv_mapper = dict(zip(list(range(M)), np.unique(df["book_id"])))
    
    user_index = [user_mapper[i] for i in df['user_id']]
    book_index = [book_mapper[i] for i in df['book_id']]
    print(len(user_index))
    X = csr_matrix((df["rating"], (book_index, user_index)), shape=(M, N))
    
    return X, user_mapper, book_mapper, user_inv_mapper, book_inv_mapper

# %%
df['book_id'].nunique()
# Out:
# 60004

# %%
df['user_id'].nunique()
# Out:
# 67843

# %%
X, user_mapper, book_mapper,user_inv_mapper, book_inv_mapper = create_X(df)
# Out:
# 496634

# %%
X
# Out:
# <60004x67843 sparse matrix of type '<class 'numpy.int64'>'
# 	with 496634 stored elements in Compressed Sparse Row format>

# %%
book_mapper
# Out:
# {5: 0,
#  50: 1,
#  61: 2,
#  93: 3,
#  236: 4,
#  241: 5,
#  244: 6,
#  314: 7,
#  329: 8,
#  330: 9,
#  333: 10,
#  334: 11,
#  335: 12,
#  378: 13,
#  881: 14,
#  883: 15,
#  903: 16,
#  1163: 17,
#  1165: 18,
#  1166: 19,
#  1852: 20,
#  1931: 21,
#  2086: 22,
#  2231: 23,
#  2257: 24,
#  2316: 25,
#  2384: 26,
#  2391: 27,
#  2404: 28,
#  2718: 29,
#  2841: 30,
#  2848: 31,
#  2851: 32,
#  2862: 33,
#  2998: 34,
#  3008: 35,
#  3012: 36,
#  3014: 37,
#  3119: 38,
#  3120: 39,
#  3143: 40,
#  3144: 41,
#  3150: 42,
#  3155: 43,
#  3156: 44,
#  3325: 45,
#  3408: 46,
#  3540: 47,
#  3562: 48,
#  3570: 49,
#  3579: 50,
#  3580: 51,
#  3636: 52,
#  3638: 53,
#  3685: 54,
#  3742: 55,
#  3743: 56,
#  3782: 57,
#  3783: 58,
#  39978: 920,
#  39980: 921,
#  39990: 922,
#  40042: 923,
#  40081: 924,
#  40106: 925,
#  40126: 926,
#  40365: 927,
#  40787: 928,
#  40790: 929,
#  40792: 930,
#  40801: 931,
#  40804: 932,
#  40808: 933,
#  40821: 934,
#  40829: 935,
#  40831: 936,
#  40835: 937,
#  40839: 938,
#  40841: 939,
#  41099: 940,
#  41102: 941,
#  41111: 942,
#  41174: 943,
#  41319: 944,
#  41437: 945,
#  41457: 946,
#  41459: 947,
#  41463: 948,
#  41558: 949,
#  41560: 950,
#  41564: 951,
#  41573: 952,
#  41644: 953,
#  41647: 954,
#  41648: 955,
#  41649: 956,
#  41667: 957,
#  41668: 958,
#  41684: 959,
#  41757: 960,
#  41861: 961,
#  41890: 962,
#  41891: 963,
#  42036: 964,
#  42065: 965,
#  42157: 966,
#  42175: 967,
#  42278: 968,
#  42282: 969,
#  42288: 970,
#  42310: 971,
#  42318: 972,
#  42323: 973,
#  42327: 974,
#  42335: 975,
#  42337: 976,
#  42338: 977,
#  42357: 978,
#  42359: 979,
#  42362: 980,
#  42366: 981,
#  42369: 982,
#  42371: 983,
#  42375: 984,
#  42376: 985,
#  42380: 986,
#  42384: 987,
#  42400: 988,
#  42402: 989,
#  42403: 990,
#  42407: 991,
#  42410: 992,
#  42411: 993,
#  42412: 994,
#  42413: 995,
#  42414: 996,
#  42415: 997,
#  42416: 998,
#  42443: 999,
#  ...}

# %% [markdown]
# Let's check out the sparsity of our X matrix

# %%
X.shape
#[0]
X.shape[1]
# Out:
# 67843

# %%
X.count_nonzero()
# Out:
# 481022

# %%
X.shape[0]*X.shape[1]
# Out:
# 4070851372

# %%
sparsity = X.count_nonzero()/(X.shape[0]*X.shape[1])

print("Matrix sparsity:", round(sparsity*100,2))
# Out:
# Matrix sparsity: 0.01

# %% [markdown]
# Only 0.01% of cells in our user-item matrix are populated with ratings.

# %% [markdown]
# ### Writing our matrix to a file

# %% [markdown]
# We're going to save our user-item matrix. Since our matrix is represented as a scipy sparse matrix, we can use the [scipy.sparse.save_npz](https://docs.scipy.org/doc/scipy-1.1.0/reference/generated/scipy.sparse.load_npz.html) method to write the matrix to a file.

# %%
from scipy.sparse import save_npz

save_npz('user_item_matrix_books.npz', X)

# %% [markdown]
# ##  Finding similar books using k-Nearest Neighbours

# %% [markdown]
# This approach looks for the $k$ nearest neighbours of a given book by identifying $k$ points in the dataset that are closest to book $m$.
# kNN makes use of distance metrics such as:
#
# 1. Cosine similarity
# 2. Euclidean distance
# 3. Manhattan distance
# 4. Pearson correlation
#
# We are working in a M-dimensional space where M represents the number of movies in our X matrix.

# %% [markdown]
# ###  Let's fit our model: NearestNeighbors

# %%
from sklearn.neighbors import NearestNeighbors

kNN = NearestNeighbors(n_neighbors=10,  metric='cosine')
kNN
kNN.fit(X)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=10)

# %% [markdown]
# ### Let's define the book that we want to assess

# %%
book_mapper;

# %%
book_titles = dict(zip(df['book_id'], df['title']))
book_titles
# Out:
# {3636: 'The Giver (The Giver, #1)',
#  11387515: 'Wonder (Wonder #1)',
#  5: 'Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)',
#  157993: 'The Little Prince',
#  38709: 'Holes (Holes, #1)',
#  370493: 'The Giving Tree',
#  389627: 'Diary of a Wimpy Kid (Diary of a Wimpy Kid, #1)',
#  9673436: 'The Invention of Hugo Cabret',
#  24178: "Charlotte's Web",
#  78411: 'The Bad Beginning (A Series of Unfortunate Events, #1)',
#  8127: 'Anne of Green Gables (Anne of Green Gables, #1)',
#  11594337: 'The One and Only Ivan',
#  2998: 'The Secret Garden',
#  50: "Hatchet (Brian's Saga, #1)",
#  30119: 'Where the Sidewalk Ends',
#  19543: 'Where the Wild Things Are',
#  10365: 'Where the Red Fern Grows',
#  83369: 'The Mysterious Benedict Society (The Mysterious Benedict Society, #1)',
#  37190: 'The Tale of Despereaux',
#  378: 'The Phantom Tollbooth',
#  23772: 'Green Eggs and Ham',
#  37186: 'The Miraculous Journey of Edward Tulane',
#  6319: 'The BFG',
#  357664: 'Because of Winn-Dixie',
#  236093: 'The Wonderful Wizard of Oz (Oz, #1)',
#  6310: 'Charlie and the Chocolate Factory (Charlie Bucket, #1)',
#  1809465: 'Rodrick Rules (Diary of a Wimpy Kid, #2)',
#  1852: 'The Call of the Wild',
#  4948: 'The Very Hungry Caterpillar',
#  24213: "Alice's Adventures in Wonderland & Through the Looking-Glass",
#  53496: 'Walk Two Moons',
#  13023: 'Alice in Wonderland',
#  227651: 'Among the Hidden (Shadow Children, #1)',
#  11607446: 'The Wishing Spell (The Land of Stories, #1)',
#  17349203: 'Fortunately, the Milk',
#  16052012: 'Flora and Ulysses: The Illuminated Adventures',
#  10959: "Sophie's World",
#  6327: 'The Witches',
#  233093: 'The Cat in the Hat',
#  32929: 'Goodnight Moon',
#  6578293: 'Dog Days (Diary of a Wimpy Kid, #4)',
#  37732: "Are You There God? It's Me, Margaret",
#  78418: 'The Reptile Room (A Series of Unfortunate Events, #2)',
#  3293821: 'The Last Straw (Diary of a Wimpy Kid, #3)',
#  2921082: 'The Maze of Bones  (The 39 Clues, #1)',
#  34262: 'Peter and the Starcatchers (Peter and the Starcatchers, #1)',
#  191139: "Oh, The Places You'll Go!",
#  222458: 'Rules',
#  6689: 'James and the Giant Peach',
#  16054808: "Escape from Mr. Lemoncello's Library (Mr. Lemoncello's Library #1)",
#  3008: 'A Little Princess',
#  266904: 'The Penderwicks: A Summer Tale of Four Sisters, Two Rabbits, and a Very Interesting Boy (The Penderwicks #1)',
#  53498: 'Love That Dog (Jack, #1)',
#  7823678: 'The Ugly Truth (Diary of a Wimpy Kid, #5)',
#  140225: 'The Voyage of the Dawn Treader (Chronicles of Narnia, #3)',
#  438492: 'The Wide Window (A Series of Unfortunate Events, #3)',
#  11254250: 'Cabin Fever (Diary of a Wimpy Kid, #6)',
#  16101018: 'The Day the Crayons Quit',
#  5983694: 'Where the Mountain Meets the Moon',
#  13083: 'Hoot',
#  293595: 'Chicka Chicka Boom Boom',
#  767680: 'If You Give a Mouse a Cookie',
#  24612624: 'George',
#  22402972: 'Fish in a Tree',
#  7784: 'The Lorax',
#  28195: 'Inkspell (Inkworld, #2)',
#  84369: 'The Last Battle (Chronicles of Narnia, #7)',
#  65112: 'The End (A Series of Unfortunate Events, #13)',
#  15944406: 'Doll Bones',
#  77767: 'Little House on the Prairie (Little House, #2)',
#  11192642: 'Go the Fuck to Sleep',
#  1099301: 'The Name of This Book Is Secret (Secret, #1)',
#  7150174: 'The Strange Case of Origami Yoda (Origami Yoda, #1)',
#  8337: 'Little House in the Big Woods (Little House, #1)',
#  5659: 'The Wind in the Willows',
#  3685: 'Black Beauty',
#  22098550: 'Pax',
#  152380: 'Mary Poppins (Mary Poppins, #1)',
#  176327: 'The Fairy-Tale Detectives (The Sisters Grimm, #1)',
#  6345760: "The Magician's Elephant",
#  191113: "Don't Let the Pigeon Drive the Bus!",
#  13563669: 'The Third Wheel (Diary of a Wimpy Kid, #7)',
#  77390: 'Anne of Avonlea (Anne of Green Gables, #2)',
#  420282: 'The Polar Express',
#  65119: 'The Miserable Mill (A Series of Unfortunate Events, #4)',
#  352262: 'How to Train Your Dragon (How to Train Your Dragon, #1)',
#  444304: 'The Field Guide (The Spiderwick Chronicles, #1)',
#  13531024: 'This is Not My Hat',
#  7825557: 'A Tale Dark & Grimm (A Tale Dark & Grimm, #1)',
#  131123: 'The Austere Academy (A Series of Unfortunate Events, #5)',
#  125507: 'The True Story of the 3 Little Pigs',
#  7783920: 'Because of Mr. Terupt (Mr. Terupt, #1)',
#  6534132: 'The Lion and the Mouse',
#  310258: 'The Snowy Day',
#  44186: 'The Monster at the End of this Book',
#  21535019: 'The Long Haul (Diary of a Wimpy Kid, #9)',
#  20821299: 'The Book with No Pictures',
#  20575434: 'Rain Reign',
#  6054449: 'Tales from a Not-So-Fabulous Life (Dork Diaries, #1)',
#  11233988: 'I Want My Hat Back',
#  766955: 'Click, Clack, Moo: Cows That Type',
#  17733898: 'Hard Luck (Diary of a Wimpy Kid, #8)',
#  24396876: 'The Thing About Jellyfish',
#  30118: 'A Light in the Attic',
#  46677: 'Alexander and the Terrible, Horrible, No Good, Very Bad Day',
#  99107: 'Winnie-the-Pooh (Winnie-the-Pooh, #1)',
#  2325825: 'Inkdeath (Inkworld, #3)',
#  297249: 'The Boxcar Children (The Boxcar Children, #1)',
#  11737313: 'Three Times Lucky (Mo & Dale Mysteries, #1)',
#  138070: 'Flotsam',
#  31456: 'The Twits',
#  9822: 'Mrs. Frisby and the Rats of NIMH (Rats of NIMH, #1)',
#  144974: 'The Velveteen Rabbit',
#  41667: 'My Side of the Mountain (Mountain, #1)',
#  4835838: '11 Birthdays (Willow Falls, #1)',
#  19302: 'Pippi Longstocking',
#  13262061: 'Liar & Spy',
#  1062516: 'No, David!',
#  77392: 'Anne of the Island (Anne of Green Gables, #3)',
#  23310699: 'Crenshaw',
#  172327: 'The Ersatz Elevator (A Series of Unfortunate Events, #6)',
#  2159225: 'The Mysterious Benedict Society and the Perilous Journey (The Mysterious Benedict Society, #2)',
#  6693: 'Fantastic Mr. Fox',
#  13477819: 'Who Could That Be at This Hour? (All the Wrong Questions, #1)',
#  113946: 'How the Grinch Stole Christmas!',
#  42369: 'The Hundred Dresses',
#  6609748: 'The Mysterious Howling (The Incorrigible Children of Ashton Place #1)',
#  93: 'Heidi',
#  138959: 'Stuart Little',
#  25937866: 'Raymie Nightingale',
#  444347: 'Chasing Vermeer (Chasing Vermeer, #1)',
#  39963: 'A Long Way from Chicago (A Long Way from Chicago, #1)',
#  37187: 'The Tiger Rising',
#  10508431: 'Tuesdays at the Castle (Castle Glower, #1)',
#  766020: 'The Rainbow Fish',
#  824734: 'Dinosaurs Before Dark (Magic Tree House, #1)',
#  7770: 'One Fish, Two Fish, Red Fish, Blue Fish',
#  37741: 'Tales of a Fourth Grade Nothing (Fudge, #1)',
#  228696: 'Owl Moon',
#  138069: 'The Three Pigs',
#  232576: 'Harriet the Spy (Harriet the Spy #1)',
#  239810: 'The Best Christmas Pageant Ever (The Herdmans #1)',
#  8619814: 'The Emerald Atlas (The Books of Beginning, #1)',
#  8073: 'Cloudy With a Chance of Meatballs',
#  106264: 'Sarah, Plain and Tall (Sarah, Plain and Tall, #1)',
#  25222064: 'Old School (Diary of a Wimpy Kid, #10)',
#  61549: "Mr. Popper's Penguins",
#  22521973: 'Last Stop on Market Street',
#  197084: 'Are You My Mother?',
#  10637959: 'Breadcrumbs',
#  2114086: 'The Willoughbys',
#  9703979: 'A Ball for Daisy',
#  2108198: 'Odd and the Frost Giants',
#  97860: 'Tuesday',
#  18295821: 'The Adventures of Beekle: The Unimaginary Friend',
#  207802: 'Ida B. . . and Her Plans to Maximize Fun, Avoid Disaster, and (Possibly) Save the World',
#  17722973: 'The Enchantress Returns (The Land of Stories, #2)',
#  4538: 'The View from Saturday',
#  281235: 'Bunnicula (Bunnicula, #1)',
#  150037: 'The Vile Village (A Series of Unfortunate Events, #7)',
#  2768169: 'The Underneath',
#  32979: 'The Secret of the Old Clock (Nancy Drew, #1)',
#  237665: "Kitten's First Full Moon",
#  6667: 'Boy: Tales of Childhood',
#  207153: 'Shiloh (Shiloh, #1)',
#  87220: 'Loser',
#  207266: 'The Adventures of Captain Underpants (Captain Underpants, #1)',
#  324277: 'The Carnivorous Carnival (A Series of Unfortunate Events, #9)',
#  297792: 'The Slippery Slope (A Series of Unfortunate Events, #10)',
#  15779: 'Sideways Stories from Wayside School (Wayside School #1)',
#  474858: 'A Bad Case of Stripes',
#  20878809: 'The Julian Chapter',
#  19156898: 'The Fourteenth Goldfish',
#  15766776: 'Rump: The True Story of Rumpelstiltskin',
#  517344: 'Clementine (Clementine, #1)',
#  17262290: 'Journey (Journey Trilogy, #1)',
#  11360892: "Balloons Over Broadway: The True Story of the Puppeteer of Macy's Parade",
#  161656: 'The Tail of Emily Windsnap (Emily Windsnap, #1)',
#  98573: 'Harold and the Purple Crayon',
#  77270: 'The Jungle Book',
#  9677870: 'Press Here',
#  267972: 'Wait Till Helen Comes',
#  65110: 'The Penultimate Peril (A Series of Unfortunate Events, #12)',
#  24271: 'Skellig (Skellig, #1)',
#  65111: 'The Grim Grotto (A Series of Unfortunate Events, #11)',
#  18222556: 'A Snicker of Magic',
#  26030734: 'The Wild Robot (The Wild Robot, #1)',
#  39980: 'A Year Down Yonder (A Long Way from Chicago, #2)',
#  24335: 'The Trumpet of the Swan',
#  125404: 'The Indian in the Cupboard (The Indian in the Cupboard, #1)',
#  13083239: 'The Fantastic Flying Books of Mr. Morris Lessmore',
#  3552023: 'One False Note (The 39 Clues, #2)',
#  8112318: 'The Candymakers (The Candymakers, #1)',
#  3579: 'The Complete Anne of Green Gables Boxed Set (Anne of Green Gables, #1-8)',
#  858513: 'Chrysanthemum',
#  240130: 'The Paper Bag Princess',
#  130580: 'Old Yeller (Old Yeller, #1)',
#  1325218: 'Scary Stories to Tell in the Dark (Scary Stories, #1)',
#  83346: 'Through the Looking-Glass, and What Alice Found There',
#  6687: 'Charlie and the Great Glass Elevator (Charlie Bucket, #2)',
#  958277: 'Junie B. Jones and the  Stupid Smelly Bus (Junie B. Jones, #1)',
#  475339: 'Madeline',
#  6690: 'Danny the Champion of the World',
#  25324132: 'Auggie & Me: Three Wonder Stories (Wonder #1.5, 1.6, 1.7)',
#  6871646: 'Pete the Cat: I Love My White Shoes',
#  11312: 'Over Sea, Under Stone (The Dark Is Rising, #1)',
#  62111: 'The Swiss Family Robinson',
#  62151: 'The Higher Power of Lucky (The Hard Pan Trilogy, #1)',
#  770051: 'Olivia',
#  12065943: 'Extra Yarn',
#  18419: 'The Kissing Hand',
#  232109: 'The Mouse and the Motorcycle (Ralph S. Mouse, #1)',
#  24819508: "Finding Winnie: The True Story of the World's Most Famous Bear",
#  19321: 'The Tale of Peter Rabbit',
#  10425811: 'Liesl & Po',
#  328802: 'Totto-chan: The Little Girl at the Window',
#  315882: "Henry's Freedom Box: A True Story from the Underground Railroad",
#  460548: 'Go, Dog. Go!',
#  23310161: 'The Day the Crayons Came Home',
#  386286: 'Julie of the Wolves (Julie of the Wolves, #1)',
#  65118: 'The Hostile Hospital (A Series of Unfortunate Events, #8)',
#  15790852: 'The Dark',
#  8044557: 'All My Friends Are Dead',
#  348573: 'The Borrowers (The Borrowers, #1)',
#  77394: "Anne's House of Dreams (Anne of Green Gables, #5)",
#  22571259: 'The Honest Truth',
#  12969560: "The Hero's Guide to Saving Your Kingdom (The League of Princes, #1)",
#  525995: 'Jumanji',
#  275000: 'Fire and Ice (Warriors, #2)',
#  29291: 'Make Way for Ducklings',
#  23281919: 'Circus Mirandus',
#  34898: "My Father's Dragon (My Father's Dragon, #1)",
#  457762: 'Sylvester and the Magic Pebble',
#  105999: 'Dear Mr. Henshaw (Leigh Botts, #1)',
#  91244: 'Beezus and Ramona (Ramona, #1)',
#  20706320: 'A Grimm Warning (The Land of Stories, #3)',
#  22917: "The Complete Grimm's Fairy Tales",
#  7846067: 'We are in a Book! (Elephant & Piggie, #13)',
#  14781201: 'I Funny: A Middle School Story (I Funny, #1)',
#  18222716: 'Greenglass House (Greenglass House, #1)',
#  301736: 'Guess How Much I Love You',
#  773951: 'The Story of Ferdinand',
#  786256: 'Stellaluna',
#  1258121: 'The Lemonade War (The Lemonade War, #1)',
#  225038: 'Half Magic (Tales of Magic, #1)',
#  13259987: 'Creepy Carrots!',
#  87226: 'Crash',
#  8036440: 'Interrupting Chicken',
#  208146: "Grandfather's Journey",
#  1653655: 'Swindle (Swindle, #1)',
#  775597: 'Caps for Sale: A Tale of a Peddler, Some Monkeys and Their Monkey Business',
#  24384: 'The Cricket in Times Square',
#  35805: "The Capture (Guardians of Ga'Hoole, #1)",
#  268917: 'The Doll People (Doll People, #1)',
#  17334578: 'Locomotive',
#  80674: 'Superfudge (Fudge, #3)',
#  74532: "George's Marvellous Medicine",
#  147732: 'Miss Nelson Is Missing! (Miss Nelson, #1)',
#  2769817: 'The House in the Night',
#  16963: 'The Hello, Goodbye Window',
#  13228487: 'The Dragonet Prophecy (Wings of Fire, #1)',
#  1000751: 'Pollyanna (Pollyanna, #1)',
#  13337050: 'Dragons Love Tacos',
#  2930911: 'Hate That Cat (Jack, #2)',
#  233637: 'The Hidden Staircase (Nancy Drew #2)',
#  1535111: 'A Crooked Kind of Perfect',
#  815234: 'The Napping House',
#  282773: "Olive's Ocean",
#  181077: 'Sadako and the Thousand Paper Cranes',
#  674749: 'The Ordinary Princess',
#  18053786: 'The Storybook of Legends (Ever After High, #1)',
#  3562: 'Emily of New Moon (Emily, #1)',
#  235127: 'No Talking',
#  65840: 'Anne of Windy Poplars (Anne of Green Gables, #4)',
#  8252: 'Farmer Boy (Little House, #3)',
#  444381: 'The Princess and the Goblin  (Princess Irene and Curdie, #1)',
#  537296: 'Frog and Toad Are Friends (Frog and Toad, #1)',
#  20708771: 'The Princess in Black (The Princess in Black, #1)',
#  13588082: 'Each Kindness',
#  401679: 'Llama Llama Red Pajama',
#  5861926: 'The Sword Thief (The 39 Clues, #3)',
#  6696465: 'Finally (Willow Falls, #2)',
#  207569: 'The Sign of the Beaver',
#  7779: 'Horton Hears a Who!',
#  903: 'The Egypt Game (Game, #1)',
#  9642662: 'Me...Jane',
#  11824: 'The Whipping Boy',
#  205821: 'Caddie Woodlawn  (Caddie Woodlawn #1)',
#  133526: 'Blueberries for Sal',
#  56728: 'You Are Special (Wemmicksville, #1)',
#  967494: 'The Mitten',
#  169413: 'Eggs',
#  17165875: 'Mr. Wuffles!',
#  10284324: 'Pie',
#  22718727: 'Book Scavenger (Book Scavenger, #1)',
#  1013383: 'The Gruffalo',
#  201126: "We're Going on a Bear Hunt",
#  343718: "A Dog's Life: The Autobiography of a Stray",
#  91253: 'Ramona Quimby, Age 8 (Ramona, #6)',
#  12125: 'Homecoming (Tillerman Cycle, #1)',
#  6164358: "The Mysterious Benedict Society and the Prisoner's Dilemma (The Mysterious Benedict Society, #3)",
#  417780: "Why Mosquitoes Buzz in People's Ears",
#  303472: 'Among the Impostors (Shadow Children, #2)',
#  25051: 'Mrs. Piggle-Wiggle (Mrs. Piggle Wiggle, #1)',
#  161099: 'Good Night, Mr. Tom',
#  13617210: 'Goldilocks and the Three Dinosaurs',
#  17331434: 'The Year of Billy Miller',
#  108980: 'Ivy and Bean (Ivy and Bean, #1)',
#  712807: 'Ruby Holler',
#  160943: "Martin's Big Words: The Life of Dr. Martin Luther King Jr.",
#  7150178: 'Big Nate: In a Class by Himself (Big Nate Novels, #1)',
#  10168924: 'Blackout',
#  18570357: 'What Do You Do with an Idea?',
#  65113: 'A Series of Unfortunate Events Box: The Complete Wreck (Books 1-13)',
#  9252036: 'The Penderwicks at Point Mouette (The Penderwicks, #3)',
#  10806008: 'Peter Nimble and His Fantastic Eyes (Peter Nimble, #1)',
#  825081: "Lilly's Purple Plastic Purse",
#  815158: 'Rapunzel',
#  17910570: 'Ophelia and the Marvelous Boy',
#  8274537: 'Tales from a Not-So-Popular Party Girl (Dork Diaries, #2)',
#  153540: 'The Little House',
#  669427: 'Lawn Boy',
#  118230: 'My Friend Rabbit',
#  78039: 'Ramona the Pest (Ramona, #2)',
#  13414183: 'Better Nate Than Ever (Better Nate Than Ever #1)',
#  18225037: 'Absolutely Almost',
#  12875557: 'Pete the Cat and His Four Groovy Buttons',
#  20708761: 'Sam and Dave Dig a Hole',
#  858514: 'Wemberly Worried',
#  826585: 'If You Give a Pig a Pancake',
#  765148: "Giraffes Can't Dance",
#  15780279: 'A Tangle of Knots',
#  194755: 'Esio Trot',
#  8282: 'The Long Winter (Little House, #6)',
#  835202: 'A Chair for My Mother',
#  206962: 'Hop On Pop',
#  1918702: 'Lon Po Po: A Red-Riding Hood Story from China',
#  6670: 'The Magic Finger',
#  6761339: 'The Dreamer',
#  817982: 'Stone Fox',
#  765654: 'Ish',
#  77770: 'These Happy Golden Years (Little House, #8)',
#  303460: 'Among the Betrayed (Shadow Children, #3)',
#  10444: 'Ballet Shoes (Shoes, #1)',
#  426625: 'Fancy Nancy',
#  420297: 'Curious George',
#  10803806: 'Darth Paper Strikes Back (Origami Yoda, #2)',
#  37739: 'Blubber',
#  581409: 'Strega Nona',
#  278264: 'Wringer',
#  105551: 'Fox in Socks',
#  10336: 'The Last of the Really Great Whangdoodles',
#  7882: 'On the Banks of Plum Creek  (Little House, #4)',
#  598117: 'Sounder',
#  295834: 'The Unusual Suspects (The Sisters Grimm, #2)',
#  5972040: 'Beyond the Grave (The 39 Clues #4)',
#  191117: "Don't Let the Pigeon Stay Up Late!",
#  659759: "I Ain't Gonna Paint No More!",
#  897680: 'When Sophie Gets Angry -- Really, Really Angry',
#  21348: "Aesop's Fables",
#  20172134: 'Nightmares! (Nightmares!, #1)',
#  774001: 'Amelia Bedelia  (Amelia Bedelia #1)',
#  6150990: 'Dying to Meet You (43 Old Cemetery Road, #1)',
#  820517: 'Joey Pigza Swallowed the Key (Joey Pigza, #1)',
#  9327053: 'Small as an Elephant',
#  348489: 'Snowflake Bentley',
#  18383325: 'The Most Magnificent Thing',
#  6678: 'Going Solo',
#  22341: 'The Wolves in the Walls',
#  826584: 'If You Give a Moose a Muffin',
#  16285053: 'That Is Not a Good Idea!',
#  7909: 'Betsy-Tacy (Betsy-Tacy, #1)',
#  18405521: "Separate Is Never Equal: Sylvia Méndez and Her Family's Fight for Desegregation",
#  15791063: 'Flora and the Flamingo',
#  9827810: 'Eight Keys',
#  27064348: "Ms. Bixby's Last Day",
#  25387393: "Mr. Lemoncello's Library Olympics (Mr. Lemoncello's Library, #2)",
#  7493149: 'Mirror Mirror: A Book of Reverso Poems',
#  28645670: 'They All Saw a Cat',
#  20696727: 'The Right Word: Roget and His Thesaurus',
#  7118768: 'Ninth Ward',
#  36638: 'The Wolves of Willoughby Chase (The Wolves Chronicles, #1)',
#  7662594: 'Chalk',
#  322351: 'How to Eat Fried Worms',
#  122967: 'The Ugly Duckling',
#  1145862: 'Stand Tall, Molly Lou Melon',
#  1908511: 'The Pigeon Wants a Puppy!',
#  23604390: 'The Princess and the Pony',
#  17461: 'Misty of Chincoteague (Misty, #1)',
#  6443349: 'Percy Jackson and the Olympians Boxed Set (Percy Jackson and the Olympians, #1-5)',
#  22693811: 'The Penderwicks in Spring (The Penderwicks, #4)',
#  551876: 'Tikki Tikki Tembo',
#  25745002: 'Mother Bruce',
#  7224717: 'City Dog, Country Frog',
#  10332: 'Mandy',
#  17846011: 'The Pigeon Needs a Bath!',
#  13152282: 'The Extraordinary Education of Nicholas Benedict (The Mysterious Benedict Society, #0.5)',
#  7769: "Dr. Seuss's ABC",
#  773276: 'Good Night, Gorilla',
#  6124878: 'Duck! Rabbit!',
#  119247: 'The Great Brain (Great Brain #1)',
#  17332435: 'The Boy on the Porch',
#  17350491: 'Rooftoppers',
#  9462672: 'True',
#  336161: 'The Grouchy Ladybug',
#  515905: 'Knuffle Bunny Too: A Case of Mistaken Identity (Knuffle Bunny, #2)',
#  731804: 'Pinkalicious',
#  34053: 'Just So Stories',
#  7616655: 'Bink & Gollie (Bink & Gollie, #1)',
#  99296: 'Diary of a Worm',
#  280277: "Lucinda's Secret (The Spiderwick Chronicles, #3)",
#  140181: 'Zen Shorts',
#  17290220: 'Rosie Revere, Engineer',
#  197512: 'The Pigeon Finds a Hot Dog!',
#  33158525: 'Wishtree',
#  428035: 'Each Little Bird that Sings',
#  11211540: 'Stuck',
#  220596: 'Not a Box',
#  15815400: 'Exclamation Mark',
#  10372: 'Summer of the Monkeys',
#  807968: "Molly Moon's Incredible Book of Hypnotism (Molly Moon, #1)",
#  515904: 'There is a Bird on Your Head! (Elephant & Piggie, #4)',
#  682920: 'The Little Mouse, the Red Ripe Strawberry, and the Big Hungry Bear',
#  22477286: 'Listen, Slowly',
#  163465: 'The Great Gilly Hopkins',
#  233722: "Kristy's Great Idea (The Baby-Sitters Club, #1)",
#  23735067: 'Waiting',
#  10065: 'Wayside School Is Falling Down (Wayside School #2)',
#  15798116: 'Mistakes Were Made (Timmy Failure, #1)',
#  129771: 'The Other Side',
#  23611997: "An Author's Odyssey (The Land of Stories, #5)",
#  18576: 'Everything on a Waffle (Coal Harbour #1)',
#  58922: 'The Runaway Bunny',
#  7926: 'All-of-a-Kind Family (All-of-a-Kind Family, #1)',
#  179565: 'The Marvelous Land of Oz (Oz, #2)',
#  334818: 'Miss Rumphius',
#  17333265: 'Mr. Tiger Goes Wild',
#  164531: 'The Railway Children',
#  6562659: 'All the World',
#  105549: 'The Sneetches and Other Stories',
#  2164318: 'Ways to Live Forever',
#  196970: 'The Night Before Christmas',
#  159666: 'The Birchbark House',
#  845403: "Mufaro's Beautiful Daughters: An African Tale",
#  88455: 'The Chocolate Touch',
#  37738: 'Freckle Juice',
#  361487: 'Becoming Naomi León',
#  14570: 'Eight Cousins (Eight Cousins, #1)',
#  77395: 'Rainbow Valley (Anne of Green Gables, #7)',
#  616833: 'Smoky Night',
#  12159951: 'Green',
#  37191: 'Mercy Watson to the Rescue (Mercy Watson #1)',
#  180617: 'Pinocchio',
#  26244910: 'Thunder Boy Jr.',
#  11737306: 'One Cool Friend',
#  127179: 'Library Lion',
#  3173438: 'School of Fear (School of Fear, #1)',
#  948526: 'The Knight at Dawn (Magic Tree House, #2)',
#  12891160: 'Middle School: Get Me Out of Here!  (Middle School, #2)',
#  164539: 'Bridge to Terabithia',
#  348564: 'Flat Stanley (Flat Stanley, #1)',
#  30122: 'The Missing Piece',
#  532069: 'Pink and Say',
#  15991959: 'Wednesdays in the Tower (Castle Glower, #2)',
#  857448: 'Harry the Dirty Dog',
#  160629: 'A Bear Called Paddington (Paddington, #1)',
#  15798648: 'The Matchbox Diary',
#  10886703: 'Nicholas St. North and the Battle of the Nightmare King (The Guardians, #1)',
#  28686931: 'A Child of Books',
#  11556479: 'The Duckling Gets a Cookie!?',
#  822392: 'Ginger Pye (The Pyes, #1)',
#  95144: 'In the Night Kitchen',
#  231821: 'The Incredible Journey',
#  17369219: 'When Did You See Her Last? (All the Wrong Questions, #2)',
#  18222557: 'Half a Chance',
#  8466286: 'The Hidden Gallery (The Incorrigible Children of Ashton Place #2)',
#  867248: 'Bear Snores On',
#  22509955: 'The Terrible Two (The Terrible Two, #1)',
#  41684: 'The Jungle Books',
#  109521: 'I Like Myself!',
#  10893214: 'The Cavendish Home for Boys and Girls',
#  9676990: 'Goodnight, Goodnight, Construction Site',
#  277191: 'The Ironwood Tree (The Spiderwick Chronicles, #4)',
#  303455: 'Among the Free (Shadow Children, #7)',
#  1033346: "Kensuke's Kingdom",
#  22249668: "Red: A Crayon's Story",
#  624744: 'Leonardo, the Terrible Monster',
#  69499: 'The Wanderer',
#  8559036: 'The Thing About Luck',
#  570633: 'Harris and Me',
#  6389704: 'In Too Deep (The 39 Clues, #6)',
#  6455548: 'NERDS: National Espionage, Rescue, and Defense Society (NERDS, #1)',
#  15727792: "Chu's Day (Chu, #1)",
#  298730: 'Among the Barons (Shadow Children, #4)',
#  621739: 'Millions of Cats',
#  47558: 'The Gashlycrumb Tinies (The Vinegar Works, #1)',
#  562763: 'Scaredy Squirrel',
#  177246: 'Room on the Broom',
#  857528: 'Call It Courage',
#  20758093: "365 Days of Wonder: Mr. Browne's Book of Precepts",
#  18079557: 'The Ghosts of Tupelo Landing (Mo & Dale Mysteries, #2)',
#  598160: 'Polar Bear, Polar Bear, What Do You Hear?',
#  20718289: 'Hansel and Gretel',
#  153865: 'Captain Underpants and the Attack of the Talking Toilets (Captain Underpants, #2)',
#  64316: 'The White Mountains (The Tripods, #1)',
#  235117: 'The School Story',
#  7737900: 'The Familiars (The Familiars, #1)',
#  125190: 'Swallows and Amazons (Swallows and Amazons, #1)',
#  595586: 'Bark, George',
#  45181: 'Five Children and It (Five Children, #1)',
#  103386: 'The Spiderwick Chronicles Box Set (The Spiderwick Chronicles, #1-5)',
#  103814: 'Enemy Pie',
#  3157876: 'Do-It-Yourself Book',
#  25311520: 'Save Me a Seat',
#  29563587: 'Dragonwatch (Dragonwatch #1)',
#  286901: 'We are the Ship: The Story of Negro League Baseball',
#  16250904: "Unicorn Thinks He's Pretty Great",
#  835010: 'The Keeping Quilt',
#  6659537: 'The Night Fairy',
#  25817074: 'All Rise for the Honorable Perry T. Cook',
#  613866: 'Igraine the Brave',
#  7784196: 'Knuffle Bunny Free: An Unexpected Diversion (Knuffle Bunny, #3)',
#  143728: 'How to Be a Pirate (How to Train Your Dragon, #2)',
#  5530988: 'The Curious Garden',
#  7949530: 'Children Make Terrible Pets',
#  16702384: 'Battle Bunny',
#  24820301: 'The Story of Diva and Flea',
#  6697305: 'Storm Warning (The 39 Clues, #9)',
#  13642600: 'A Splash of Red: The Life and Art of Horace Pippin',
#  13429619: 'Sleep Like a Tiger',
#  6393047: "The Viper's Nest (39 Clues, #7)",
#  601598: 'The Spider and the Fly',
#  27247476: 'The Thank You Book (Elephant & Piggie, #25)',
#  6671: 'The Wonderful Story of Henry Sugar and Six More',
#  2591769: 'Allergic to Girls, School, and Other Scary Things (Alvin Ho, #1)',
#  858719: 'Clifford the Big Red Dog',
#  13545345: 'Tales from a Not-So-Graceful Ice Princess (Dork Diaries, #4)',
#  8229399: 'Big Nate Strikes Again (Big Nate Novels, #2)',
#  17471114: 'Sparky!',
#  438024: "Let's Pretend This Never Happened (Dear Dumb Diary #1)",
#  122125: 'How Do Dinosaurs Say Good Night?',
#  8203202: 'Touch Blue',
#  816752: 'The Castle in the Attic (The Castle in the Attic, #1)',
#  13521501: 'Starry River of the Sky',
#  10508526: 'The Chronicles of Harris Burdick: 14 Amazing Authors Tell the Tales',
#  80877: 'Voices in the Park',
#  8248: 'By the Shores of Silver Lake  (Little House, #5)',
#  12727215: 'Gangsta Granny',
#  23719217: 'Took: A Ghost Story',
#  133547: 'Everyone Poops',
#  53495: 'Chasing Redbird',
#  885187: 'The Doorbell Rang',
#  635083: 'Owen',
#  25785698: 'The Night Gardener',
#  548609: 'Surviving the Applewhites (Applewhites, #1)',
#  1967067: 'Blueberry Girl',
#  9466024: 'Pete the Cat: Rocking in My School Shoes',
#  16650268: 'The Watermelon Seed',
#  18651970: 'A Path Begins (The Thickety #1)',
#  981463: 'The Relatives Came',
#  109548: 'Black and White',
#  17190361: 'Everything I Need To Know I Learned From a Little Golden Book',
#  13623948: 'The Great Unexpected',
#  577542: 'Rikki-Tikki-Tavi',
#  6536509: '14 Cows for America',
#  6694: 'The Giraffe and the Pelly and Me',
#  9975313: 'The Humming Room',
#  17140549: 'The Invisible Boy',
#  303454: 'Among the Brave (Shadow Children, #5)',
#  143126: 'The 13 Clocks',
#  13438677: 'The Spindlers',
#  839077: 'The Three Little Wolves and the Big Bad Pig',
#  13591296: 'The Secret of the Fortune Wookiee  (Origami Yoda, #3)',
#  839263: 'David Goes To School',
#  17349055: 'The Real Boy',
#  280313: 'The Rough-Face Girl',
#  80670: 'Otherwise Known as Sheila the Great (Fudge #2)',
#  160192: 'Joyful Noise: Poems for Two Voices',
#  310272: "There's a Wocket in My Pocket!",
#  8253: 'Little Town on the Prairie  (Little House, #7)',
#  1670602: 'Those Shoes',
#  10659536: 'Every Thing on It',
#  26482: 'The Music of Dolphins',
#  18005: 'How I Became a Pirate',
#  423156: 'King of the Wind: The Story of the Godolphin Arabian',
#  105552: 'Mr. Brown Can Moo! Can You?',
#  15815410: 'Hold Fast',
#  11043410: 'Heart and Soul: The Story of America and African Americans',
#  593236: 'Runny Babbit: A Billy Sook',
#  13547289: 'Tales from a Not-So-Smart Miss Know-It-All (Dork Diaries, #5)',
#  39106: 'Rosa',
#  132541: 'The Secret of Platform 13',
#  31215005: 'The Legend of Rock Paper Scissors',
#  3118349: 'One',
#  716944: 'Owl Babies',
#  17269359: 'Treasure Hunters (Treasure Hunters, #1)',
#  966757: 'On My Honor',
#  114308: 'Swimmy',
#  11301: 'Horton Hatches the Egg',
#  20307024: 'Wolfie the Bunny',
#  139987: 'The Snow Queen',
#  246546: 'An Old-Fashioned Girl',
#  7952209: 'The Kneebone Boy',
#  25785754: 'Maybe a Fox',
#  7309806: 'Lulu and the Brontosaurus',
#  17488: 'Five on a Treasure Island (Famous Five, #1)',
#  78408: 'Lemony Snicket: The Unauthorized Autobiography (A Series of Unfortunate Events companion)',
#  60177: 'Ozma of Oz (Oz, #3)',
#  331701: 'Stone Soup',
#  12448586: 'Boy + Bot',
#  13591670: 'Unspoken: A Story from the Underground Railroad',
#  22750286: 'Sidewalk Flowers',
#  165068: 'The Jesus Storybook Bible: Every Story Whispers His Name',
#  6250208: 'Extra Credit',
#  14955390: 'On a Beam of Light: A Story of Albert Einstein',
#  491578: 'The White Giraffe (Animal Healer, #1)',
#  13547802: 'Fairest of All (Whatever After, #1)',
#  308540: 'The Haunted Mask (Goosebumps, #11)',
#  125662: 'Say Cheese and Die! (Goosebumps, #4)',
#  294442: 'Journey to the River Sea',
#  28217808: 'Moo',
#  403722: 'Missing May',
#  20821124: 'Once Upon an Alphabet: Short Stories for All the Letters',
#  9473008: 'Of Thee I Sing: A Letter to My Daughters',
#  153542: 'Mike Mulligan and His Steam Shovel',
#  2241348: 'Little Blue Truck',
#  7295428: 'Back of the Bus',
#  4290363: 'Naked Mole Rat Gets Dressed',
#  8139824: 'Dave the Potter: Artist, Poet, Slave',
#  6545536: "The Emperor's Code (The 39 Clues, #8)",
#  22926534: 'Unusual Chickens for the Exceptional Poultry Farmer',
#  6609700: 'Keeper',
#  103815: 'Among the Enemy (Shadow Children, #6)',
#  6328: 'Revolting Rhymes',
#  5022157: 'I Need My Monster',
#  1928405: 'Eleven',
#  10353049: 'Under Wildwood (Wildwood Chronicles, #2)',
#  47693: 'The Day I Swapped My Dad for Two Goldfish',
#  7740753: 'No Passengers Beyond This Point',
#  119297: 'The Girl Who Loved Wild Horses',
#  275325: 'The Butter Battle Book',
#  7023148: 'Instructions',
#  198719: 'The Girl with the Silver Eyes',
#  6949680: 'LMNO Peas',
#  906543: 'The Family Under the Bridge',
#  682751: 'Animalia',
#  14403: 'The Story of Ruby Bridges',
#  215014: 'The Year of the Dog',
#  11982396: 'Glory Be',
#  29313: 'Sector 7',
#  11891485: "And Then It's Spring",
#  24968109: 'What Pet Should I Get?',
#  12860772: 'Summer of the Gypsy Moths',
#  37737: 'Fudge-a-Mania (Fudge, #4)',
#  750035: 'The Dollhouse Murders',
#  6629316: 'Big Red Lollipop',
#  22875394: 'Interstellar Cinderella',
#  280240: 'Rumpelstiltskin',
#  363973: 'The Little Old Lady Who Was Not Afraid of Anything',
#  13414963: 'Mr. Terupt Falls Again (Mr. Terupt, #2)',
#  16718342: 'The Noisy Paint Box',
#  275247: 'Little Lord Fauntleroy',
#  114701: 'Into the Land of the Unicorns (Unicorn Chronicles, #1)',
#  286136: 'Leven Thumps and the Whispered Secret (Leven Thumps, #2)',
#  1381691: 'Emmy and the Incredible Shrinking Rat (Emmy, #1)',
#  13642591: 'Hokey Pokey',
#  7128581: 'Shark vs. Train',
#  74998: 'The Magic Faraway Tree (The Faraway Tree, #2)',
#  347151: 'Understood Betsy',
#  143717: 'Pirates Past Noon (Magic Tree House, #4)',
#  1767779: 'Five Little Monkeys Jumping on the Bed',
#  2200542: 'The Calder Game (Chasing Vermeer, #3)',
#  20388087: "Julia's House for Lost Creatures",
#  295801: 'The House with a Clock in Its Walls (Lewis Barnavelt, #1)',
#  13664: 'Catwings (Catwings, #1)',
#  8366238: 'The Trouble With Chickens (J.J. Tully Mystery #1)',
#  20708773: 'Quest (Journey Trilogy, #2)',
#  529252: 'Double Love (Sweet Valley High, #1)',
#  24963: 'Greenwitch (The Dark Is Rising, #3)',
#  12924291: 'Jake and Lily',
#  6121819: 'Red Sings from Treetops: A Year in Colors',
#  6644750: 'The Sandwich Swap',
#  225542: 'Leo the Late Bloomer',
#  372319: "Jo's Boys (Little Women, #3)",
#  15818081: "Brave Girl: Clara and the Shirtwaist Makers' Strike of 1909",
#  18349884: 'My Teacher Is a Monster! (No, I Am Not.)',
#  18552623: 'Radiant Child: The Story of Young Artist Jean-Michel Basquiat',
#  1743853: "Moving Day (Allie Finkle's Rules for Girls, #1)",
#  225274: 'Song and Dance Man',
#  507402: 'Little Pea',
#  53580: 'The Going-To-Bed Book',
#  920780: 'Duck On A Bike',
#  6788767: 'Athena the Brain (Goddess Girls, #1)',
#  218152: 'The Three Questions',
#  28439554: 'Penguin Problems',
#  22323647: 'Please, Mr. Panda',
#  7331: 'Letters from Father Christmas',
#  33282947: 'See You in the Cosmos',
#  13595647: 'This Moose Belongs to Me',
#  6855239: 'The Quiet Book',
#  132391: 'The Little Mermaid',
#  12975886: 'Capture the Flag (Silver Jaguar Society Mysteries #1)',
#  8725928: 'The Unseen Guest (The Incorrigible Children of Ashton Place, #3)',
#  667234: 'The Cat in the Hat Comes Back',
#  21965059: 'The Bear Ate Your Sandwich',
#  526077: 'Hey, Al',
#  8296: 'The First Four Years  (Little House, #9)',
#  4600: 'Moo, Baa, La La La!',
#  28507895: 'Ada Twist, Scientist',
#  23167689: 'Trombone Shorty',
#  159061: 'Go Away, Big Green Monster!',
#  301141: 'Lost and Found (The Boy, #2)',
#  30125: 'The Missing Piece Meets the Big O',
#  16074339: 'The True Blue Scouts of Sugar Man Swamp',
#  18475599: 'The Farmer and the Clown',
#  16074748: 'Tales from a Not-So-Happy Heartbreaker (Dork Diaries, #6)',
#  22635853: 'If You Plant a Seed',
#  12180277: 'Chloe and the Lion',
#  8039941: 'Art & Max',
#  537338: 'The Red Book',
#  25152641: 'The Key to Extraordinary',
#  55734: 'The Mysteries of Harris Burdick',
#  12426366: 'Fake Mustache',
#  22082059: 'A Handful of Stars',
#  576335: 'Chitty Chitty Bang Bang (Chitty Chitty Bang Bang, #1)',
#  967511: 'Rascal',
#  9732272: 'Junonia',
#  22749711: "Drum Dream Girl: How One Girl's Courage Changed Music",
#  25387851: 'The Fox and the Star',
#  33016249: 'Good Night Stories for Rebel Girls: 100 Tales of Extraordinary Women',
#  489972: 'The Snowman',
#  342994: 'The Little Match Girl',
#  91247: 'Ramona and Her Father (Ramona, #4)',
#  7622249: 'How Rocket Learned to Read',
#  32940857: 'Worlds Collide (The Land of Stories, #6)',
#  8471013: 'Perfect Square',
#  24580: 'The Adventures of Tom Sawyer & Adventures of Huckleberry Finn',
#  55749: 'Zathura',
#  28863341: 'What Do You Do with a Problem?',
#  16650266: 'Count the Monkeys',
#  825679: 'The World According to Humphrey (According to Humphrey, #1)',
#  734542: 'Freight Train',
#  8768: 'Today I Feel Silly  Other Moods That Make My Day',
#  773507: "Emily's Quest (Emily, #3)",
#  420404: 'Yertle the Turtle and Other Stories',
#  402141: 'The Star of Kazan',
#  4883204: 'The Boy in the Dress',
#  13529139: 'I am a Pole',
#  176626: "King Bidgood's in the Bathtub",
#  3002254: 'That Book Woman',
#  351530: 'What Do You Do With a Tail Like This?',
#  17080054: 'The Book of Lost Things (Mister Max #1)',
#  821292: 'My Name Is Yoon',
#  107465: 'Moses: When Harriet Tubman Led Her People to Freedom',
#  858590: 'The Gardener',
#  5698821: 'Llama Llama Misses Mama',
#  18967185: 'Nana in the City',
#  11148223: "Mr. and Mrs. Bunny—Detectives Extraordinaire! (The Bunny's #1)",
#  28351: 'And to Think That I Saw it on Mulberry Street',
#  820273: 'Sheep in a Jeep',
#  26875552: 'As Brave As You',
#  20484662: 'Dory Fantasmagory',
#  15812770: 'Stranded (Stranded, #1)',
#  94803: 'Frog and Toad Together (Frog and Toad, #2)',
#  5019: 'The Saturdays (The Melendy Family, #1)',
#  3418156: 'Kenny and the Dragon',
#  789344: 'Encyclopedia Brown, Boy Detective (Encyclopedia Brown, #1)',
#  18269507: 'Demon Dentist',
#  20518873: 'This Book Just Ate My Dog!',
#  46306: 'The Complete Fairy Tales',
#  25785760: 'Ida, Always',
#  17243953: 'Hi, Koo!',
#  18689810: 'Tales from a Not-So-Glam TV Star (Dork Diaries, #7)',
#  6668: 'The Enormous Crocodile',
#  12711152: "Horten's Miraculous Mechanisms: Magic, Mystery,  a Very Strange Adventure",
#  34601: 'Snow Treasure',
#  37377: 'On the Night You Were Born',
#  1165509: 'Lost Treasure of the Emerald Eye (Geronimo Stilton, #1)',
#  7041525: 'Mr Stink',
#  21469062: 'Winnie: The True Story of the Bear Who Inspired Winnie-the-Pooh',
#  590552: 'Chicken Soup with Rice: A Book of Months',
#  1296415: 'Mouse Paint',
#  26030671: 'Are We There Yet?',
#  6348133: 'Binky the Space Cat',
#  31314: 'Barnyard Dance',
#  23528363: 'The Only Child',
#  13586798: 'The Three Ninja Pigs',
#  17930108: 'Rules of Summer',
#  568476: 'Henry Huggins (Henry Huggins, #1)',
#  809849: 'Dear Zoo: A Lift-the-Flap Book',
#  385250: "The Jolly Postman, or Other People's Letters",
#  13792593: 'Open This Little Book',
#  28210996: 'I Dissent: Ruth Bader Ginsburg Makes Her Mark',
#  13170028: 'Bear Has a Story to Tell',
#  24300: 'Poppy (Tales of Dimwood Forest, #1)',
#  120840: 'David Gets In Trouble',
#  7327326: 'Half Upon a Time (Half Upon a Time, #1)',
#  21416421: 'Waiting is Not Easy! (Elephant & Piggie, #22)',
#  10842675: 'Waiting for the Magic',
#  79121: 'The Happy Prince',
#  300946: 'The Red Tree',
#  366300: 'Walter the Farting Dog',
#  20917828: 'You Are (Not) Small',
#  14823980: 'A Fine Dessert: Four Centuries, Four Families, One Delicious Treat',
#  543086: "Tom's Midnight Garden",
#  6729699: 'A Nest for Celeste: A Story About Art, Inspiration, and the Meaning of Home',
#  17465447: 'The Grimm Conclusion (A Tale Dark & Grimm, #3)',
#  10178007: 'Bigger than a Bread Box',
#  1111741: "George's Secret Key to the Universe",
#  5665292: 'Rhyming Dust Bunnies',
#  25785628: 'Freedom in Congo Square',
#  39518: 'Gilda Joyce: Psychic Investigator (Gilda Joyce, #1)',
#  23310214: "Pip Bartlett's Guide to Magical Creatures (Pip Bartlett, #1)",
#  9239452: 'Shadow',
#  7171946: 'The Boss Baby',
#  17529: 'Rebecca of Sunnybrook Farm',
#  15814436: 'Ball',
#  22484277: 'I Wish You More',
#  7797: 'Ten Apples Up On Top!',
#  40081: 'The Meanest Doll in the World (Doll People, #2)',
#  197515: 'Today I Will Fly! (Elephant & Piggie, #1)',
#  5834917: 'Faith, Hope, and Ivy June',
#  3308834: 'Bats at the Library',
#  17269361: "Knock Knock: My Dad's Dream for Me",
#  10284337: 'Floors',
#  857920: 'Silverwing (Silverwing, #1)',
#  883051: 'Tacky the Penguin',
#  20821347: 'Firebird: Ballerina Misty Copeland Shows a Young Girl How to Dance Like the Firebird',
#  89551: 'Ramona and Her Mother (Ramona, #5)',
#  134028: 'My Many Colored Days',
#  13448343: "I'm Bored",
#  11737012: 'Goodnight iPad: A Parody for the Next Generation',
#  22546584: 'Story Thieves (Story Thieves, #1)',
#  8526585: 'My Name Is Mina (Skellig, #0.5)',
#  156979: 'The Bungalow Mystery (Nancy Drew, #3)',
#  5499910: 'Spoon',
#  13624190: "Let's Go for a Drive! (Elephant & Piggie, #18)",
#  13623795: 'Nelson Mandela',
#  6055161: 'Dragonbreath (Dragonbreath, #1)',
#  857556: 'Goldilocks and the Three Bears',
#  19312: 'The Brothers Lionheart',
#  2865944: 'If You Give a Cat a Cupcake',
#  37731: "Just as Long as We're Together",
#  1703186: 'Chester',
#  45343: "The Nixie's Song (Beyond the Spiderwick Chronicles, #1)",
#  9465166: 'Hooray for Amanda & Her Alligator!',
#  7540259: 'Memoirs of a Goldfish',
#  9529502: 'Big Nate on a Roll (Big Nate Novels, #3)',
#  324974: "Sophie's World: A Novel about the History of Philosophy",
#  87976: 'The Tower Treasure (Hardy Boys, #1)',
#  223845: 'My Friend is Sad (Elephant & Piggie, #2)',
#  30201160: 'Short',
#  914519: 'Junie B. Jones Loves Handsome Warren (Junie B. Jones, #7)',
#  843019: 'Eating the Alphabet',
#  241074: 'The Tiny Seed',
#  30312747: 'Not Quite Narwhal',
#  189182: 'The Story About Ping',
#  1300700: 'Alphabet City',
#  8999818: 'I Broke My Trunk! (Elephant & Piggie, #14)',
#  13546400: 'Olivia and the Fairy Princesses',
#  2769831: 'A Couple of Boys Have the Best Week Ever',
#  911579: 'Bread and Jam for Frances',
#  9661136: 'Should I Share My Ice Cream? (Elephant & Piggie, #15)',
#  22443909: 'The Imaginary',
#  3265484: 'The Composer is Dead',
#  19314: "Ronia, the Robber's Daughter",
#  739840: 'Bambi',
#  89730: 'The Outcasts of 19 Schuyler Place',
#  58382: 'Through My Eyes',
#  15944573: 'A Big Guy Took My Ball! (Elephant & Piggie, #19)',
#  12892470: 'The Year of the Book (Anna Wang #1)',
#  196283: 'Junie B. Jones and the Mushy Gushy Valentime (Junie B. Jones, #14)',
#  111027: 'Tar Beach',
#  886512: 'Jamberry',
#  23754884: 'The Green Ember (The Green Ember #1)',
#  13642528: 'The Terrible Thing That Happened to Barnaby Brocket',
#  79879: 'From Head to Toe',
#  18769869: 'The Misadventures of the Family Fletcher (Family Fletcher, #1)',
#  690483: 'Glass Slipper, Gold Sandal: A Worldwide Cinderella',
#  824239: 'The Recess Queen',
#  17043027: 'Josephine: The Dazzling Life of Josephine Baker',
#  511527: 'Double Act',
#  18656207: 'The Meaning of Maggie',
#  7844798: 'Can I Play Too? (Elephant & Piggie, #12)',
#  31247841: 'Triangle',
#  15926775: "Sophie's Squash",
#  20256610: 'Ivan: The Remarkable True Story of the Shopping Mall Gorilla',
#  15814452: 'The Center of Everything',
#  175824: 'Gone-Away Lake (Gone-Away Lake, #1)',
#  734072: 'Mirette on the High Wire',
#  23309640: 'Float',
#  15814439: 'Mustache Baby',
#  23281892: 'Harriet the Invincible (Hamster Princess, #1)',
#  897296: 'Too Many Tamales',
#  770038: 'Is Your Mama a Llama?',
#  541521: 'The Doll in the Garden',
#  53494: 'Granny Torrelli Makes Soup',
#  18754759: "Shouldn't You Be in School? (All the Wrong Questions, #3)",
#  15799165: 'Bluebird',
#  857418: 'The Carrot Seed',
#  3171606: 'Wave',
#  17802191: 'The Surprise Attack of Jabba the Puppett (Origami Yoda, #4)',
#  10047243: 'Hound Dog True',
#  937381: 'The First Strawberries',
#  30312547: "Amina's Voice",
#  20413: "A Child's Garden of Verses",
#  8514027: 'Mission Unstoppable (The Genius Files, #1)',
#  125542: 'Stay Out of the Basement  (Goosebumps, #2)',
#  1297810: 'I Stink!',
#  48811: 'Nancy Drew: #1-64',
#  6620483: 'Zoobreak (Swindle, #2)',
#  23197599: 'The Worst Class Trip Ever (The Worst, #1)',
#  28818766: 'The Journey',
#  74720: 'The Beatrice Letters',
#  161653: 'Emily Windsnap and the Monster from the Deep (Emily Windsnap, #2)',
#  500799: 'Mick Harte Was Here',
#  99791: 'Golem',
#  22749702: 'Stick and Stone',
#  7785: 'I Can Read With My Eyes Shut!',
#  389623: 'Diary of a Wombat',
#  8253491: 'Storm Runners (Storm Runners #1)',
#  28449045: 'When the Sea Turned to Silver',
#  826582: 'If You Take a Mouse to School',
#  235128: 'A Week in the Woods',
#  831842: 'Behind the Attic Wall',
#  12098668: 'Chopsticks',
#  1161994: 'Martina the Beautiful Cockroach: A Cuban Folktale',
#  24774: 'Clockwork',
#  325421: 'The Story of Doctor Dolittle (Doctor Dolittle, #1)',
#  815262: 'Silly Sally',
#  413256: 'The Boy Who Was Raised by Librarians',
#  41861: 'John, Paul, George & Ben',
#  1967071: 'The Dangerous Alphabet',
#  17773504: 'The Snatchabook',
#  378518: "The Wedding Planner's Daughter (Wedding Planner's Daughter, #1)",
#  35806: "The Journey (Guardians of Ga'Hoole, #2)",
#  15673: 'Wayside School Gets A Little Stranger (Wayside School #3)',
#  22718809: 'From the Notebooks of a Middle School Princess (From the Notebooks of a Middle School Princess, #1)',
#  826095: 'Miracles on Maple Hill',
#  89545: 'Socks',
#  16002003: 'The Boy Who Loved Math: The Improbable Life of Paul Erdos',
#  42447: 'Strawberry Girl',
#  24905361: 'Leo: A Ghost Story',
#  325636: 'The Summer of the Swans',
#  11042036: 'Secrets at Sea',
#  17320985: 'A Boy and a Jaguar',
#  3124179: 'Ten Little Fingers and Ten Little Toes',
#  10353508: 'Swirl by Swirl: Spirals in Nature',
#  108302: 'The Greedy Triangle',
#  28963877: "Nanette's Baguette",
#  28008154: 'The Uncorker of Ocean Bottles',
#  2904330: 'Are You Ready to Play Outside? (Elephant & Piggie, #7)',
#  377889: 'The Children of Green Knowe (Green Knowe, #1)',
#  17383992: 'Tap the Magic Tree',
#  15660: 'The Stranger',
#  1025223: 'Shipwreck (Island, #1)',
#  2647293: "Alice's Adventures in Wonderland (Alice's Adventures in Wonderland, #1)",
#  1969280: 'Iggy Peck, Architect',
#  971239: 'How to Speak Dragonese (How to Train Your Dragon, #3)',
#  7739868: 'Funny Business',
#  9537743: "Where's Walrus?",
#  423211: 'Maniac Magee',
#  7172082: 'Zombie in Love',
#  191170: 'Giggle, Giggle, Quack',
#  7911: 'Five Little Peppers and How They Grew',
#  246936: 'Yo! Yes?',
#  7999433: 'Dark Emperor and Other Poems of the Night',
#  57605: 'Pat the Bunny',
#  6645867: "It's Raining Cupcakes",
#  2540640: 'The Gollywhopper Games',
#  25241871: 'Warren the 13th and The All-Seeing Eye',
#  853233: 'The Landry News',
#  153165: 'Whoever You Are',
#  101001: 'The Secret of Shadow Ranch (Nancy Drew, #5)',
#  20706273: 'A Perfectly Messed-Up Story',
#  18012466: 'Maple',
#  78991: 'Zoom',
#  97643: 'A Tree Is Nice',
#  835495: 'Time for Bed',
#  351018: 'Which Witch?',
#  24305: 'The Secret School',
#  555999: 'Someday',
#  23399241: 'Woof (Bowser and Birdie #1)',
#  857501: 'Hand, Hand, Fingers, Thumb',
#  10118: 'Saint George and the Dragon',
#  28875: "Three Tales Of My Father's Dragon",
#  413158: 'Put Me in the Zoo',
#  41668: 'My Side of the Mountain Trilogy (Mountain #1-3)',
#  7621049: 'Word After Word After Word',
#  17533: 'Rose in Bloom (Eight Cousins, #2)',
#  45183: 'The Enchanted Castle',
#  22504710: 'Castle Hangnail',
#  3231457: 'Chicken Cheeks',
#  20549446: 'Mix It Up!',
#  511635: 'Candyfloss',
#  67243: 'Dear Enemy (Daddy-Long-Legs, #2)',
#  153866: 'Captain Underpants and the Perilous Plot of Professor Poopypants (Captain Underpants, #4)',
#  6081980: 'The Chestnut King (100 Cupboards, #3)',
#  774600: 'In the Year of the Boar and Jackie Robinson',
#  773514: 'Emily Climbs (Emily, #2)',
#  ...}

# %%
book_title = book_titles[6310]
book_title
# Out:
# 'Charlie and the Chocolate Factory (Charlie Bucket, #1)'

# %%
book_id = 6310
book_ind = book_mapper[book_id]
book_ind #the value of the book id in our sparse matrix
# Out:
# 116

# %%
book_to_assess = X[book_ind]
book_to_assess
# Out:
# <1x67843 sparse matrix of type '<class 'numpy.int64'>'
# 	with 730 stored elements in Compressed Sparse Row format>

# %%
 neighbour = kNN.kneighbors(book_to_assess, return_distance=False) #Finds the K-neighbors of a point.

# %%
neighbour
# Out:
# array([[  116,   135,   136,   118,   139,   117,   537,   710,   131,
#         21045]], dtype=int64)

# %% [markdown]
# ### Coming back to the original id from the book

# %%
book_inv_mapper[116]
# Out:
# 6310

# %%
neighbour_ids = []
for i in range(1,10):
    n = neighbour.item(i) 
    neighbour_ids.append(book_inv_mapper[n])
    
neighbour_ids
# Out:
# [6687, 6689, 6327, 6693, 6319, 24178, 31456, 6670, 1728744]

# %%
print("Because you read:",book_title)
print('******************************************')
for i in neighbour_ids:
    print(book_titles[i])
# Out:
# Because you read: Charlie and the Chocolate Factory (Charlie Bucket, #1)
# ******************************************
# Charlie and the Great Glass Elevator (Charlie Bucket, #2)
# James and the Giant Peach
# The Witches
# Fantastic Mr. Fox
# The BFG
# Charlotte's Web
# The Twits
# The Magic Finger
# Sleeping Beauty (Disney Princess, 5)

# %% [markdown]
# ## Creating a function to get the recommendations

# %%
def get_recommendations(book_id, X, k,
                        metric='cosine'):
    """
    Finds k-nearest neighbours for a given movie id.
    
    Args:
        book_id: id of the movie of interest
        X: user-item utility matrix
        k: number of similar books to retrieve
        metric: distance metric for kNN calculations
    
    Returns:
        list of k similar book ID's
    """
    neighbour_ids = []
    
    book_ind = book_mapper[book_id]
    book_to_assess = X[book_ind]
    kNN = NearestNeighbors(n_neighbors=k, 
                           metric=metric)
    kNN.fit(X)

    neighbour = kNN.kneighbors(book_to_assess, return_distance=False)
    
    # We need to map each neighbour id with the right book_id
    for i in range(1,k):
        n = neighbour.item(i) #
        neighbour_ids.append(book_inv_mapper[n])

    
    
    book_titles = dict(zip(df['book_id'], df['title']))
    book_title = book_titles[book_id]
    
    print(f"Because you read", book_title, "you would love:")
    print('*********************************************************')
    for i in neighbour_ids:
        print(book_titles[i])
    
    #return neighbour_ids

# %% [markdown]
# ## Getting some recommendations

# %%
book_id = 6310

get_recommendations(book_id, X, k=6)
# Out:
# Because you read Charlie and the Chocolate Factory (Charlie Bucket, #1) you would love:
# *********************************************************
# Charlie and the Great Glass Elevator (Charlie Bucket, #2)
# James and the Giant Peach
# The Witches
# Fantastic Mr. Fox
# The BFG

# %%
book_id = 19543

get_recommendations(book_id, X, k=6)
# Out:
# Because you read Where the Wild Things Are you would love:
# *********************************************************
# The Snowy Day
# The Very Hungry Caterpillar
# Green Eggs and Ham
# Goodnight Moon
# The Cat in the Hat

# %%
book_id = 13194740

get_recommendations(book_id, X, k=6)
# Out:
# Because you read Gnarbunga you would love:
# *********************************************************
# The Invisible Princess
# Ramadan Moon
# Cousin Ruth's Tooth
# Dark Night
# One North Star: A Counting Book

# %%
book_id = 275325

get_recommendations(book_id, X, k=6)
# Out:
# Because you read The Butter Battle Book you would love:
# *********************************************************
# Little Bird's ABC
# The Diary of Stuffles B. Snippet
# Sunshine & Storm
# A Manatee Morning
# Raven and River

# %%
book_id = 3636

get_recommendations(book_id, X, k=6)
# Out:
# Because you read The Giver (The Giver, #1) you would love:
# *********************************************************
# Wonder (Wonder #1)
# Holes (Holes, #1)
# Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)
# The Invention of Hugo Cabret
# The Bad Beginning (A Series of Unfortunate Events, #1)

# %%
book_id = 20549446

get_recommendations(book_id, X, k=6)
# Out:
# Because you read Mix It Up! you would love:
# *********************************************************
# Telephone
# Flashlight
# My Grandfather's Coat
# Hello, My Name is Ruby
# What's New? The Zoo!: A Zippy History of Zoos

# %%
book_id = 11233988

get_recommendations(book_id, X, k=6)
# Out:
# Because you read I Want My Hat Back you would love:
# *********************************************************
# This is Not My Hat
# Extra Yarn
# The Dark
# Mr. Tiger Goes Wild
# Sam and Dave Dig a Hole

# %%
book_id = 296944
get_recommendations(book_id, X, k=6)
# Out:
# Because you read Clocks and More Clocks you would love:
# *********************************************************
# Toolbox Twins
# Clocks and More Clocks
# Polar Star
# Dudley and the Toy Keeper's Chest
# The Story of Robin Hood

# %%
book_id = book_id = 19321

get_recommendations(book_id, X, k=6)
# Out:
# Because you read The Tale of Peter Rabbit you would love:
# *********************************************************
# The Tale of Squirrel Nutkin
# The Tale of Benjamin Bunny
# The Tale of Jemima Puddle-Duck
# The Tale of Two Bad Mice
# The Tale of Tom Kitten

# %%
book_id = 28507895

get_recommendations(book_id, X, k=6)
# Out:
# Because you read Ada Twist, Scientist you would love:
# *********************************************************
# Maybe Something Beautiful: How Art Transformed a Neighborhood
# The Noisy Paint Box
# The Wheels on the Tuk Tuk
# Are We There Yet?
# Ideas Are All Around
